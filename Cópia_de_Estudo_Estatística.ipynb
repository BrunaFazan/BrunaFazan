# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunaFazan/BrunaFazan/blob/main/C%C3%B3pia_de_Estudo_Estat%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p>Amplitude de classe/Amplitude de distribuição/<p>
# <h2>DISTRIBUIÇÃO DE FREQUÊNCIA.<h2>
#
#
# Tabelas de classe e frequência, ponto médio, frequencia relativa, frequencia acumulada.

# %%
import pandas as pd
#pandas é a biblioteca que usaremos

# %%
#podemos fazer tudo isso de maneira mais sucinta:
# Conjunto de dados
import pandas as pd
data = pd.Series([128, 100, 180, 150, 200, 90, 340, 105, 85, 270,
                  200, 65, 230, 150, 150, 120, 130, 80, 230, 200,
                  110, 126, 170, 132, 140, 112, 90, 340, 170, 190])
#valors max min e n classes:
v_max = data.max()
v_min = data.min()
n_classes = 7

#distribuiçao de frequencia:
dist_freq = data.value_counts(bins=7).sort_index()

#Reconfiguração do conjunto de dados: Series para DataFrame
nova_dist_freq = pd.DataFrame(dist_freq)
nova_dist_freq = nova_dist_freq.reset_index()
nova_dist_freq.columns = ['Classe', 'Frequência']

#calculo e aplicando a amplitude de classes:
amplitude = round((v_max-v_min)/n_classes) #ao invés de round pode ser ceil tbm.
intervalos = pd.interval_range(start=v_min, end=v_max, freq=amplitude)
nova_dist_freq['Classe'] = intervalos

# Cálculo dos pontos médios das classe
pts_medios = [inter.mid for inter in intervalos]

# Inserção da coluna Pontos médios
nova_dist_freq['Pontos médios'] = pts_medios
# Cálculo e inserção das colunas de frequência relativa e acumulada
observacoes = len(data)
nova_dist_freq['Frequência relativa'] = nova_dist_freq['Frequência']/observacoes
nova_dist_freq['Frequência acumulada'] = nova_dist_freq['Frequência'].cumsum()
display(nova_dist_freq)
# Out:
#        Classe  Frequência  Pontos médios  Frequência relativa  \
# 0   (65, 104]           6           84.5             0.200000
# 1  (104, 143]           9          123.5             0.300000
# 2  (143, 182]           6          162.5             0.200000
# 3  (182, 221]           4          201.5             0.133333
# 4  (221, 260]           2          240.5             0.066667
# 5  (260, 299]           1          279.5             0.033333
# 6  (299, 338]           2          318.5             0.066667
#
#    Frequência acumulada
# 0                     6
# 1                    15
# 2                    21
# 3                    25
# 4                    27
# 5                    28
# 6                    30

# %%
#Quando um conjunto de dados é dado para nós, precisamos defini-los de alguma maneira, como:
data = pd.Series([128, 100, 180, 150, 200, 90, 340, 105, 85, 270,
                  200, 65, 230, 150, 150, 120, 130, 80, 230, 200,
                  110, 126, 170, 132, 140, 112, 90, 340, 170, 190])
#nesse caso, 'data' é igual a pd.Series, que são todos os valores dos GPS
print(data) #o print é o que faz aparecer a informação.
# Out:
# 0     128
# 1     100
# 2     180
# 3     150
# 4     200
# 5      90
# 6     340
# 7     105
# 8      85
# 9     270
# 10    200
# 11     65
# 12    230
# 13    150
# 14    150
# 15    120
# 16    130
# 17     80
# 18    230
# 19    200
# 20    110
# 21    126
# 22    170
# 23    132
# 24    140
# 25    112
# 26     90
# 27    340
# 28    170
# 29    190
# dtype: int64

# %%
# Valores máximo, mínimo e número de classes
v_max = data.max() #aqui estamos dizendo que queremos info do 'data' sendo o maior valor
v_min = data.min() #aqui estamos dizendo que queremos info do 'data' sendo o menor valor
n_classes = 7
print(f'Valor mínimo da distribuição = {v_min}') # o print vai aparecer esses valores
print(f'Valor máximo da distribuição = {v_max}')
# Out:
# Valor mínimo da distribuição = 65
# Valor máximo da distribuição = 340

# %%
dist_freq = data.value_counts(bins=7).sort_index()
#aqui, o dist_freq siginifica que queremos a frequencia dos acontecimentos.
#data é onde nossos dados estão, 'value_counts' é literalmente o que vai contar
#quantas vezes cada preço de gps apareceu em sua determinada classe, e sort_index vai ordenar em crescente.
#FREQUENCIA
print(dist_freq)
# Out:
# (64.72399999999999, 104.286]    6
# (104.286, 143.571]              9
# (143.571, 182.857]              6
# (182.857, 222.143]              4
# (222.143, 261.429]              2
# (261.429, 300.714]              1
# (300.714, 340.0]                2
# dtype: int64

# %%
# Reconfiguração do conjunto de dados: Pandas Series para Pandas DataFrame
nova_dist_freq = pd.DataFrame(dist_freq)
#aqui só vamos "organizar" as classes para aparecerem melhor, através de um dataFrame do pandas
display(nova_dist_freq)
# Out:
#                               0
# (64.72399999999999, 104.286]  6
# (104.286, 143.571]            9
# (143.571, 182.857]            6
# (182.857, 222.143]            4
# (222.143, 261.429]            2
# (261.429, 300.714]            1
# (300.714, 340.0]              2

# %%
# Resetando os índices do DataFrame
nova_dist_freq = nova_dist_freq.reset_index()
display(nova_dist_freq)
#isso serve para formatar a 'tabela' que estamos vendo
# Out:
#                           index  0
# 0  (64.72399999999999, 104.286]  6
# 1            (104.286, 143.571]  9
# 2            (143.571, 182.857]  6
# 3            (182.857, 222.143]  4
# 4            (222.143, 261.429]  2
# 5            (261.429, 300.714]  1
# 6              (300.714, 340.0]  2

# %%
# Renomeando as colunas do DataFrame
nova_dist_freq.columns = ['Classe', 'Frequência']
#nova_dist_clumns é onde estamos mexendo para formatar
#o .columns é onde queremos alterar a informação, e classe e frequencia os nomes que queremos dar.
display(nova_dist_freq)
#aqui estamos tirando o index e 0 e transformando em classe  frequencia
#mais formatação.
# Out:
#                          Classe  Frequência
# 0  (64.72399999999999, 104.286]           6
# 1            (104.286, 143.571]           9
# 2            (143.571, 182.857]           6
# 3            (182.857, 222.143]           4
# 4            (222.143, 261.429]           2
# 5            (261.429, 300.714]           1
# 6              (300.714, 340.0]           2

# %%
# Cálculo da amplitude de classe, com respectivos intervalos de classe
amplitude = round((v_max-v_min)/n_classes) #ao invés de round pode ser ceil tbm.
#a amplitude de classe se calcula fznd vmax - vmin dividido pelo numero de classes.
intervalos = pd.interval_range(start=v_min, end=v_max, freq=amplitude)
#aqui definimos o intervalo que ele vai agrupar os dados.
# o pd.interval_range vai ser definido por (start=v_min, end=v_max, freq=amplitude),
#siginificando que começa pelo menor, termina no maior e ele vai ser agrupado pela amplitude, que calculamos através da formula
print(intervalos)
# Out:
# IntervalIndex([(65, 104], (104, 143], (143, 182], (182, 221], (221, 260], (260, 299], (299, 338]], dtype='interval[int64, right]')

# %%
# Atribuição dos intervalos para a coluna Classe
nova_dist_freq['Classe'] = intervalos
#aqui colocamos os intervalos certos na coluna classe.
display(nova_dist_freq)
# Out:
#        Classe  Frequência
# 0   (65, 104]           6
# 1  (104, 143]           9
# 2  (143, 182]           6
# 3  (182, 221]           4
# 4  (221, 260]           2
# 5  (260, 299]           1
# 6  (299, 338]           2

# %%
# Cálculo dos pontos médios das classe
pts_medios = [inter.mid for inter in intervalos]
#aqui calculamos os pontos médios de todos de uma vez só. usando esse código acima.
print(pts_medios)
# Out:
# [84.5, 123.5, 162.5, 201.5, 240.5, 279.5, 318.5]

# %%
# Inserção da coluna Pontos médios
nova_dist_freq['Pontos médios'] = pts_medios
#para add a coluna só colocamos o nome da tabela, e [aqui colocamos o nome dela] = de onde vem as informações novas
display(nova_dist_freq)
# Out:
#        Classe  Frequência  Pontos médios
# 0   (65, 104]           6           84.5
# 1  (104, 143]           9          123.5
# 2  (143, 182]           6          162.5
# 3  (182, 221]           4          201.5
# 4  (221, 260]           2          240.5
# 5  (260, 299]           1          279.5
# 6  (299, 338]           2          318.5

# %%
# Cálculo e inserção das colunas de frequência relativa e acumulada
observacoes = len(data) #observações são a quantidade de ocorrencias da classe(?)
nova_dist_freq['Frequência relativa'] = nova_dist_freq['Frequência']/observacoes
#é a coluna frequencia dividida pelas observações.
nova_dist_freq['Frequência acumulada'] = nova_dist_freq['Frequência'].cumsum()
# é a soma das linhas da coluna frequencia.
#nova_dist_freq[] é assim que se coloca uma nova coluna.
display(nova_dist_freq)
# Out:
#        Classe  Frequência  Pontos médios  Frequência relativa  \
# 0   (65, 104]           6           84.5             0.200000
# 1  (104, 143]           9          123.5             0.300000
# 2  (143, 182]           6          162.5             0.200000
# 3  (182, 221]           4          201.5             0.133333
# 4  (221, 260]           2          240.5             0.066667
# 5  (260, 299]           1          279.5             0.033333
# 6  (299, 338]           2          318.5             0.066667
#
#    Frequência acumulada
# 0                     6
# 1                    15
# 2                    21
# 3                    25
# 4                    27
# 5                    28
# 6                    30

# %% [markdown]
# <h1>HISTOGRAMA:

# %%
import matplotlib.pyplot as plt
#biblioteca para construção de histogramas
# Construção do histograma
histograma = data.hist(bins=[inter.left for inter in intervalos]+[v_max],
                       color='blue', edgecolor='black', grid=False)
#isso são as configurações de como o gráfico vai ficar
histograma.set(xlabel='Preço [US$]',
               ylabel='Frequência - Número de navegadores GPS',
               title='Distribuição de frequências dos preços de GPS',
               xticks=nova_dist_freq['Pontos médios'],
               yticks=range(0, nova_dist_freq['Frequência'].max()+2, 2))
#aqui estamos realmente colocando as informações no gráfico. onde preço é o eixo X e frequencia o Y
#xticks define os numeros da linha do eixo X
#yticks define os numeros da linha do eixo Y, onde colocamos o maximo +2
plt.show()

# %%
# Construção do histograma
histograma = data.hist(bins=[inter.left for inter in intervalos]+[v_max],
                       color='green', edgecolor='black', grid=False)
# Inserção de atributos ao gráfico
histograma.set(xlabel='Preço [US$]',
               ylabel='Frequência - Número de navegadores GPS',
               title='Distribuição de frequências dos preços de GPS',
               xticks=nova_dist_freq['Pontos médios'],
               yticks=range(0,nova_dist_freq['Frequência'].max()+2,2))
#somente a partir daqui é novo
# Inserção de rótulos nas barras do histograma
barras = histograma.patches
freqs = nova_dist_freq['Frequência']
for barra, freq in zip(barras, freqs):
    altura = barra.get_height()
    histograma.text(x=barra.get_x()+barra.get_width()/2, y=altura+0.1,
                    s=freq, ha='center', va='bottom')
    #usamos isso para colocar os numeros encima das barras do histograma
plt.show()

# %% [markdown]
# <h1>Polígono de Frequência.
# <p>são gráficos que apresentam melhor exibição das freqs<p>

# %%
# Cálculo dos pontos médios fictícios
fic_esq = [pts_medios[0]-amplitude]
#o que fica a esquerda do gráfico vai ser o primeiro ponto médio [0]-amplitude]
print(f'Ponto médio fictício à esquerda = {fic_esq[0]}')
fic_dir = [pts_medios[-1]+amplitude]
#o que fica a direita é [-1]+amplitude]
print(f'Ponto médio fictício à direita = {fic_dir[0]}')
#aqui definimos os pontos ficticios para melhor compreensão do gráfico.
# Out:
# Ponto médio fictício à esquerda = 45.5
# Ponto médio fictício à direita = 357.5

# %%
# Construção dos dados com inserção dos pontos médios fictícios
x_data = fic_esq + list(nova_dist_freq['Pontos médios']) + fic_dir
# estamos colocando as informações para o eixo X, é p ficticio esquerdo + list(novadist) + ficticio direito
print(f'Valores para eixo x: {x_data}') #é o que vai aparecer no eixo x
y_data = [0] + list(nova_dist_freq['Frequência']) + [0]
#estamos colocando as informações para o eixo Y, é 0 + list(novadist) + 0
print(f'Valores para eixo y: {y_data}')
# Out:
# Valores para eixo x: [45.5, 84.5, 123.5, 162.5, 201.5, 240.5, 279.5, 318.5, 357.5]
# Valores para eixo y: [0, 6, 9, 6, 4, 2, 1, 2, 0]

# %%
# Plotagem do polígono de frequências, com diversos atributos
# a montagem desse gráfico:
plt.plot(x_data, y_data,'go--')
plt.xlabel('Preço [US$]')
plt.ylabel('Frequência - Número de navegadores GPS')
plt.title('Distribuição de frequências dos preços de GPS')
plt.xticks(x_data)
plt.yticks(range(0, nova_dist_freq['Frequência'].max()+2, 2)) #aqui é frequencia normal no eixo Y
plt.grid()

# %%
# Plotagem do polígono de frequências com frequências relativas
# o que muda será o eixo Y
y_data_rel = [y/sum(y_data) for y in y_data] #aqui é frequencia relativa no eixo Y
plt.plot(x_data, y_data_rel,'ro--')
plt.xlabel('Preço [US$]')
plt.ylabel('Frequência relativa')
plt.title('Distribuição de frequências dos preços de GPS')
plt.xticks(x_data)
plt.grid()

# %% [markdown]
# <h1> Construção de histogramas e ogivas </h1>

# %%
import pandas as pd
from math import ceil

# Conjunto de dados
data = pd.Series([128, 100, 180, 150, 200, 90, 340, 105, 85, 270,
                  200, 65, 230, 150, 150, 120, 130, 80, 230, 200,
                  110, 126, 170, 132, 140, 112, 90, 340, 170, 190])

# Valores máximo, mínimo e número de classes
v_max = data.max()
v_min = data.min()
n_classes = 7

# Distribuição de frequência
dist = data.value_counts(bins=7).sort_index()

# Reconfiguração do conjunto de dados: Series para DataFrame
dist_freq = pd.DataFrame(dist)
dist_freq = dist_freq.reset_index()
dist_freq.columns = ['Classe','Frequência']

# Cálculo da amplitude de classe, com respectivos intervalos de classe
amplitude = ceil((v_max-v_min)/n_classes)
intervalos = pd.interval_range(start=v_min, end=v_max+amplitude, freq=amplitude)

# Atribuição dos intervalos para a coluna Classe
dist_freq['Classe'] = intervalos

# Cálculo dos pontos médios das classe
pts_medios = [inter.mid for inter in intervalos]

# Inserção da coluna Pontos médios
dist_freq['Pontos médios'] = pts_medios

# Cálculo e inserção das colunas de frequência relativa e acumulada
observacoes = len(data)
dist_freq['Frequência relativa'] = dist_freq['Frequência']/observacoes
dist_freq['Frequência acumulada'] = dist_freq['Frequência'].cumsum()
display(dist_freq)
# Out:
#        Classe  Frequência  Pontos médios  Frequência relativa  \
# 0   (65, 105]           6           85.0             0.200000
# 1  (105, 145]           9          125.0             0.300000
# 2  (145, 185]           6          165.0             0.200000
# 3  (185, 225]           4          205.0             0.133333
# 4  (225, 265]           2          245.0             0.066667
# 5  (265, 305]           1          285.0             0.033333
# 6  (305, 345]           2          325.0             0.066667
#
#    Frequência acumulada
# 0                     6
# 1                    15
# 2                    21
# 3                    25
# 4                    27
# 5                    28
# 6                    30

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import numpy as np

# Construção do histograma
histograma =  data.hist(bins=n_classes, color='lightblue', edgecolor='black',
                       grid=False, weights=np.ones_like(data)/len(data))
#aqui definimos a fromatação do gráfico.

# Inserção de atributos ao gráfico
histograma.set(xlabel='Preço [US$]',
               ylabel='Frequência relativa\n(navegadores GPS)',
               title='Distribuição de frequências dos preços de GPS',
               xticks=dist_freq['Pontos médios'])
#aqui nomeamos o que cada coisa vai ser, como a barra horizontal "preço"
# Inserção de rótulos nas barras do histograma
barras = histograma.patches
freqs = dist_freq['Frequência relativa']
ajuste_texto = 0.001
for barra, freq in zip(barras, freqs):
    altura = barra.get_height()
    texto_freq = f'{freq*100:.1f}%'
    histograma.text(x=barra.get_x()+barra.get_width()/2, y=altura+ajuste_texto,
                    s=texto_freq, ha='center', va='bottom')

# Ajuste do eixo vertical para exibição das porcentagens
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %%
# Construção dos dados: vamos usar os extremos direitos de cada classe
#com a frequencia normal.
x_data = [dist_freq['Classe'][0].left] + [extremos.right for extremos in dist_freq['Classe']]
y_data = [0] + list(dist_freq['Frequência acumulada'])
#de todos esse bloco de código, só adicionamos essas duas primeiras linhas,
#onde definimos x_data como a coluna classe[0].left + [extremos.right for extremos in dist_freq['Classe']]
#e Y sendo [0] + list(dist_freq['Frequência acumulada'])
# Plotagem da ogiva, com diversos atributos
plt.plot(x_data, y_data,'ro--')
plt.xlabel('Preço [US$]')
plt.ylabel('Frequência acumulada\nNúmero de navegadores GPS')
plt.title('Distribuição de frequências dos preços de GPS')
plt.xticks(x_data)
plt.grid()

# Registro das frequências acumuladas
for x, y in zip(x_data, y_data):
  plt.text(x=x, y=y+0.5, s=f'{y}', ha='center', va='bottom', color='red')
plt.show()

# %%
# Construção dos dados: vamos usar os extremos direitos de cada classe
#aqui é basicamente a mesma coisa, mas sendo freq relativa
# mudando o ódigo assim:
x_data = [dist_freq['Classe'][0].left] + [extremos.right for extremos in dist_freq['Classe']]
y_data = np.array([0] + list(dist_freq['Frequência acumulada']))/observacoes

# Plotagem da ogiva, com diversos atributos
plt.plot(x_data, y_data,'ro--')
plt.xlabel('Preço [US$]')
plt.ylabel('Frequência acumulada\nPorcentagem de navegadores GPS')
plt.title('Distribuição de frequências dos preços de GPS')
plt.xticks(x_data)
plt.grid()

# Registro das porcentagens acumuladas
for x, y in zip(x_data, y_data):
  plt.text(x=x, y=y+0.01, s=f'{y*100:.1f}%',
           ha='right', va='bottom', color='red')

# Ajuste do eixo vertical para exibição das porcentagens
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %% [markdown]
# <h1> Gráfico de Pizza: </H1>
# Usamos o matplotlib no método pie.

# %%
import matplotlib.pyplot as plt
import pandas as pd
#importantíssimo se lembrar de importar as bibliotecas para os gráficos funcionarem.
#precisamos importar os dados para  Gráfico de pizza.
# Criação do conjunto de dados
dados = [['Tecnólogo', 942], ['Bacharelado', 1716],
         ['Mestrado', 731], ['Doutorado', 164]]
tabela = pd.DataFrame(dados, columns=['Título', 'Frequência'])
tabela['Porcentagem'] = tabela['Frequência']/tabela['Frequência'].sum()*100 #aqui tivemos que completar,
#fazendo a conta da porcentagem. freq/freq*100
display(tabela)

# Gráfico de pizza
pizza = plt.pie(x=tabela['Frequência'], labels=tabela['Título'],
                autopct='%1.1f%%', wedgeprops={'edgecolor': 'black'},
                shadow=True)
#tivemos que colocar as configurações do gráfico.
plt.show()
# Out:
#         Título  Frequência  Porcentagem
# 0    Tecnólogo         942    26.512806
# 1  Bacharelado        1716    48.297214
# 2     Mestrado         731    20.574163
# 3    Doutorado         164     4.615818

# %% [markdown]
# <h1> Gráfico de Pareto

# %%
#criação de grafico simples
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import numpy as np
#bibliotecas!!!!
dados = pd.DataFrame({'Medalhas': [44, 65, 104, 82, 88]})
dados.index = ['Alemanha', 'Grã-Bretanha',
               'Estados unidos', 'Rússia', 'China']
dados = dados.sort_values(by='Medalhas', ascending=False)
display(dados)
# Construção do gráfico de Pareto
plt.bar(x=dados.index, height=dados['Medalhas'],
        color='cyan', edgecolor='black')
plt.xlabel('Principais países no quadro de medalhas')
plt.ylabel('Número de medalhas')
plt.title('Medalhas em Londres 2012')
plt.show()
#isso pode servir para fazer caber todas as descrições:
# plt.figure(figsize=(10, 6))
# Out:
#                 Medalhas
# Estados unidos       104
# China                 88
# Rússia                82
# Grã-Bretanha          65
# Alemanha              44

# %%
# Criação do conjunto de dados
# criação de gráfico de pareto
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import numpy as np
#bibliotecas!!!!
dados = pd.DataFrame({'Valores': [4.2, 15.1, 12.3, 1.1, 1.7]})
dados.index = ['Erro\nAdm', 'Roubo\nfuncionários',
               'Roubo\nlojas', 'Desconhecida', 'Fraude\nvendas']

# Organizando os dados em ordem decrescente
dados = dados.sort_values(by='Valores', ascending=False)

# Criando a coluna da porcentagem acumulada
dados['PorcAcum'] = dados['Valores'].cumsum()/dados['Valores'].sum()*100
display(dados)

## Criação do gráfico de Pareto
# Definição das cores
cor_barra = 'steelblue'
cor_linha = 'red'
tam_linha = 4

# Construindo o gráfico básico (gráfico de barras)
fig, pareto = plt.subplots()
pareto.bar(x=dados.index, height=dados['Valores'], color=cor_barra)
pareto.set(xlabel='Causas apuradas',
           ylabel='Bilhões de dólares',
           title = 'Principais causas de redução de estoque')

# Inserção de rótulos nas barras do gráfico de Pareto
barras = pareto.patches
valores = dados['Valores']
for barra, valor in zip(barras, valores):
    altura = barra.get_height()
    pareto.text(x=barra.get_x()+barra.get_width()/2, y=altura,
                s=valor, ha='center', va='bottom', color=cor_barra)

# Adicionando linha de porcentagem acumulada (leitura no eixo secundário)
linha = pareto.twinx()
linha.plot(dados.index, dados['PorcAcum'], color=cor_linha,
           marker="o", ms=tam_linha)
linha.yaxis.set_major_formatter(PercentFormatter())
linha.tick_params(axis='y', colors=cor_linha)
#adicionamos essa parte para colocar as porcentagens acumuladas.


# Registro das porcentagens acumuladas
for x, y in zip(dados.index, dados['PorcAcum']):
  plt.text(x=x, y=y-0.3, s=f'{y:.1f}%',
           ha='left', va='top', color=cor_linha)
plt.show()
# Out:
#                      Valores    PorcAcum
# Roubo\nfuncionários     15.1   43.895349
# Roubo\nlojas            12.3   79.651163
# Erro\nAdm                4.2   91.860465
# Fraude\nvendas           1.7   96.802326
# Desconhecida             1.1  100.000000

# %% [markdown]
# <h1>Dados emparelhados - Diagrama de dispersão </h1>
#  Esse conjunto de dados descreve várias características físicas, tais como o comprimento e a largura das pétalas e sépalas (em centímetros).

# %%
# Leitura dos dados "externos": módulo de datasets da biblioteca Scikit-learn
from sklearn.datasets import load_iris
#biblioteca!!!

# Obtém os dados em objeto da classe 'Bunch' e cria um DataFrame correspondente
Iris_dataset = load_iris()
iris = pd.DataFrame(data=Iris_dataset.data, columns=Iris_dataset.feature_names)
display(iris.head())

# Construção do diagrama de dispersão
#colocamos os dados das flores, como tamanho das petalas e sepalas
plt.scatter(iris['petal length (cm)'], iris['petal width (cm)'])
plt.scatter(iris['sepal length (cm)'], iris['sepal width (cm)'])
#adicionamos os dois acima
plt.xlabel('Comprimento [cm]')
plt.ylabel('Largura [cm]')
plt.title('Conjunto de dados - Íris de Fisher')
plt.legend(['Pétala', 'Sépala'])
plt.grid()
plt.show()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#outra manira de fazer isso sem importar dados de fora
# Leitura dos dados "externos": módulo de datasets da biblioteca Scikit-learn
import matplotlib.pyplot as plt

# Dados de exemplo (substitua pelos seus próprios dados)
alunos_por_professor = [17,1, 17,5, 18,9, 17,1, 20,0, 18,6, 14,4, 16,5, 13,3, 18,4]
salario_professores = [28,7, 47,5, 32,8, 28,1, 40,3, 33,8, 49,8, 37,5, 42,5, 31,9]

# Criar o gráfico de dispersão
plt.scatter(alunos_por_professor, salario_professores, label='Pontos de Dispersão', color='blue', marker='o')

# Configurar rótulos e título
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Diagrama de Dispersão')

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()

# %% [markdown]
# <h1> Dados emparelhados - Séries Temporais </h1>

# %%
# Criação do conjunto de dados usando dicionários
dados = pd.DataFrame({'Assinantes': [134.6, 148.1, 169.5, 194.5, 219.7, 243.4,
                                     262.7, 276.6, 292.8, 306.3, 321.7],
                      'Conta média':[47.42, 49.46, 49.49, 49.52, 49.30, 49.94,
                                     48.54, 49.57, 47.47, 47.23, 47.16]})
dados.index = list(range(2002, 2013))
display(dados)

# Séries temporais
fig, assinantes = plt.subplots()
assinantes.plot(dados.index, dados['Assinantes'], 'bo-') #adicionamos
assinantes.set(xlabel='Ano', ylabel='Milhões de assinantes',
               title = 'Telefonia celular')
assinantes.tick_params(axis='y', colors='blue')
conta = assinantes.twinx() #adicionamos
conta.plot(dados.index, dados['Conta média'], 'go-')
conta.set(ylabel='Conta média [US$]')
conta.tick_params(axis='y', colors='green')
# Out:
#       Assinantes  Conta média
# 2002       134.6        47.42
# 2003       148.1        49.46
# 2004       169.5        49.49
# 2005       194.5        49.52
# 2006       219.7        49.30
# 2007       243.4        49.94
# 2008       262.7        48.54
# 2009       276.6        49.57
# 2010       292.8        47.47
# 2011       306.3        47.23
# 2012       321.7        47.16

# %% [markdown]
# <h1>Média, mediana, moda </h1>

# %%
import pandas as pd
# Conjunto de dados
data = pd.Series([20, 20, 20, 20, 20, 20, 21,
                  21, 21, 21, 22, 22, 22, 23,
                  23, 23, 23, 24, 24, 65])

# %%
import matplotlib.pyplot as plt
# Construção do histograma
#aqui contruimos, colocamos o eixo x e as classes
amp = data.max()-data.min()
eixo_x = list(range(data.min(), data.max()+1, 5))
classes =  pd.interval_range(start=data.min()-0.5, end=data.max()+0.5, freq=1)
histograma = data.hist(bins=[classe.left for classe in classes]+[data.max()+0.5],
                       color='blue', edgecolor='black', grid=False)

# Inserção de atributos ao gráfico
histograma.set(xlabel='Idade', ylabel='Frequência',
               title='Distribuição de frequências das idades em uma turma de alunos',
               xticks=eixo_x)
plt.show()

# %%
# Cálculo das medidas de tendência central
#para calcular a media e mediana é simples, so colocar data.mean() para média
#e data.median para mediana
media = data.mean()
print(f'A média da distribuição de idades é {media}.')
mediana = data.median()
print(f'A mediana da distribuição de idades é {mediana}.')
moda = list(data.mode()) # mode retorna uma série de dados!
#como o mode retorna vários dados, colocamos o list(data.mode())
print(f'A moda da distribuição de idades é {moda[0]}.')
# Out:
# A média da distribuição de idades é 23.75.
# A mediana da distribuição de idades é 21.5.
# A moda da distribuição de idades é 20.

# %% [markdown]
# <h1> Média Ponderada

# %%
# Criação do conjunto de dados
notas = pd.DataFrame({'Notas':[86, 96, 82, 98, 100],
                      'Pesos':[0.5, 0.15, 0.2, 0.1, 0.05]})
notas.index = ['Média do teste', 'Prova bimestral', 'Prova final',
               'Informática', 'Dever de casa']
display(notas)

# Cálculo da média ponderada - Usando a definição
media_ponderada = sum(notas['Notas'] * notas['Pesos']) / notas['Pesos'].sum()
#aqui calculando manualmente são as colunas notas e pesos multiplicadas, somadas, depois divididas pela soma da coluna pesos
print(f'A média final é {media_ponderada}.')

# Cálculo da média ponderada - Usando o numpy
import numpy as np
media_ponderada = np.average(a=notas['Notas'], weights=notas['Pesos'])
#e aqui é a biblioteca que faz a conta automaticamente pra vc com o código acima
print(f'A média final é {media_ponderada}.')
# Out:
#                  Notas  Pesos
# Média do teste      86   0.50
# Prova bimestral     96   0.15
# Prova final         82   0.20
# Informática         98   0.10
# Dever de casa      100   0.05
# A média final é 88.6.
# A média final é 88.6.

# %%
# Função para o cálculo da média ponderada de um agrupamento
#para calcular de uma vez a média ponderada de mais de um grupo
def media_ponderada(dataframe, col_valores, col_pesos):
    valores = dataframe[col_valores]
    pesos = dataframe[col_pesos]
    return (valores*pesos).sum() / pesos.sum()
    #informamos os pesos que cada info tem

# Criação do conjunto de dados
produtos = pd.DataFrame({'Nome_item': ['Chocolate', 'Chocolate', 'Chocolate',
                                       'Biscoito', 'Biscoito', 'Biscoito',
                                       'Sorvete', 'Sorvete', 'Sorvete'],
                          'Preço': [90, 50, 86, 87, 42, 48, 68, 92, 102],
                          'Peso': [4, 2, 3, 5, 6, 5, 3, 7, 5]})
display(produtos)

# Média ponderada agrupada pelo nome do item
medias = produtos.groupby('Nome_item').apply(media_ponderada, 'Preço', 'Peso')
display(medias)
#o código acima nos informa as médias ponderadas de cada um

# Preço méio de cada item
for indice in range(len(medias)):
  print(f'Preço médio do {medias.index[indice]}: {medias[indice]:.2f}')
# Out:
#    Nome_item  Preço  Peso
# 0  Chocolate     90     4
# 1  Chocolate     50     2
# 2  Chocolate     86     3
# 3   Biscoito     87     5
# 4   Biscoito     42     6
# 5   Biscoito     48     5
# 6    Sorvete     68     3
# 7    Sorvete     92     7
# 8    Sorvete    102     5
# Nome_item
# Biscoito     57.937500
# Chocolate    79.777778
# Sorvete      90.533333
# dtype: float64
# Preço médio do Biscoito: 57.94
# Preço médio do Chocolate: 79.78
# Preço médio do Sorvete: 90.53

# %% [markdown]
# # **Média de uma distribuição de frequência**
# Voltemos ao exemplo da distribuição de frequência dos preços de navegadores GPS. Qual o preço médio de um navegador?

# %%
from math import ceil
# Conjunto de dados
data = pd.Series([128, 100, 180, 150, 200, 90, 340, 105, 85, 270,
                  200, 65, 230, 150, 150, 120, 130, 80, 230, 200,
                  110, 126, 170, 132, 140, 112, 90, 340, 170, 190])

# Valores máximo, mínimo e número de classes
v_max = data.max()
v_min = data.min()
n_classes = 7

# Distribuição de frequência
dist = data.value_counts(bins=7).sort_index()

# Reconfiguração do conjunto de dados: Series para DataFrame
dist = pd.DataFrame(dist)
dist = dist.reset_index()
dist.columns = ['Classe', 'Frequência']

# Cálculo da amplitude de classe, com respectivos intervalos de classe
amplitude = ceil((v_max-v_min)/n_classes)
intervalos = pd.interval_range(start=v_min, end=v_max+amplitude, freq=amplitude)

# Atribuição dos intervalos para a coluna Classe
dist['Classe'] = intervalos

# Cálculo dos pontos médios das classe
pts_medios = [inter.mid for inter in intervalos]

# Inserção da coluna Pontos médios
dist['Pontos médios'] = pts_medios
display(dist)

# Cálculo da preço médio
#tivemos que add as infos abaixo
obs = len(data)
preco =  (dist['Frequência']*dist['Pontos médios']).sum()/obs
#aqui temos a média de distribuição de frequencia
#a soma das duas colunas, freq e ponto médios, dividido pela freq total
print(f'O preço médio de um navegador GPS é de US${preco:.2f}.')
# Out:
#        Classe  Frequência  Pontos médios
# 0   (65, 105]           6           85.0
# 1  (105, 145]           9          125.0
# 2  (145, 185]           6          165.0
# 3  (185, 225]           4          205.0
# 4  (225, 265]           2          245.0
# 5  (265, 305]           1          285.0
# 6  (305, 345]           2          325.0
# O preço médio de um navegador GPS é de US$162.33.

# %% [markdown]
# <h1>Medidas de Variacao:</h1>
# Desvio padrao populacional.
# Desvio padrao amostral, variancia amostral.

# %%
#aqui vamos calcular media, mediana e desvios padrao dos itens abaixo.

import pandas as pd
import numpy as np

# Conjunto de dados
#contrucao tabela
tabela = pd.DataFrame({'Aluno':['Alisa','Bobby','Cathrine','Madonna',
                              'Rocky','Sebastian','Jaqueline','Rahul',
                              'David','Andrew','Ajay','Teresa'],
                      'P1':[62,47,55,74,31,77,85,63,42,32,71,57],
                      'P2':[89,87,67,55,47,72,76,79,44,92,99,69],
                      'P3':[56,86,77,45,73,62,74,89,71,67,97,68]})
display(tabela)
# Out:
#         Aluno  P1  P2  P3
# 0       Alisa  62  89  56
# 1       Bobby  47  87  86
# 2    Cathrine  55  67  77
# 3     Madonna  74  55  45
# 4       Rocky  31  47  73
# 5   Sebastian  77  72  62
# 6   Jaqueline  85  76  74
# 7       Rahul  63  79  89
# 8       David  42  44  71
# 9      Andrew  32  92  67
# 10       Ajay  71  99  97
# 11     Teresa  57  69  68

# %%
# Construindo um novo DataFrame, coluna a coluna
#tabela
''' A atribuição True ao parâmetro numeric_only garante que apenas colunas
numéricas sejam utilizadas. Para o cálculo do desvio padrão, é preciso usar
ddof=0 para informar que os dados são proveninetes de uma população (o valor
default, ddof=1, é usado para o desvio padrão amostral.'''
est_provas =pd.DataFrame(tabela.mean(axis=0, numeric_only=True), columns=['Média']) #media
est_provas['Mediana'] = tabela.median(axis=0, numeric_only=True) #mediana
est_provas['DesvPad'] = tabela.std(axis=0, ddof=0, numeric_only=True) #desvio padrao
amps = [tabela['P'+str(i)].max() - tabela['P'+str(i)].min() for i in range(1,4)]
est_provas['Amplitudes'] = amps
display(est_provas)

# Distribuição mais homogênea
print('*** Prova mais homogênea ***')
homogenea = est_provas.loc[est_provas['DesvPad'] == est_provas['DesvPad'].min()]
display(homogenea)

# Usando o método agg (nesse caso, o método std é usado com ddof=1)
print('Uso do método agg')
tabela.agg(['mean', 'std', 'median'])
# Out:
#         Média  Mediana    DesvPad  Amplitudes
# P1  58.000000     59.5  16.703293          54
# P2  73.000000     74.0  16.901676          55
# P3  72.083333     72.0  13.744443          52
# *** Prova mais homogênea ***
#         Média  Mediana    DesvPad  Amplitudes
# P3  72.083333     72.0  13.744443          52
# Uso do método agg
# <ipython-input-5-3a2150591ce1>:20: FutureWarning: ['Aluno'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   tabela.agg(['mean', 'std', 'median'])
#                P1         P2         P3
# mean    58.000000  73.000000  72.083333
# std     17.446021  17.653225  14.355603
# median  59.500000  74.000000  72.000000

# %%
# Médias de desvios padrão por aluno
''' É preciso usar axis=1 para o cálculo nas linhas do DataFrame.
CUIDADO: o retorno é um objeto Series, logo é preciso usasar list() para
armazenar em uma coluna de um DataFrame.'''
est_alunos = pd.DataFrame(tabela.mean(axis=1, numeric_only=True), columns=['Média'])
est_alunos.index = list(tabela['Aluno'])
est_alunos['DesvPad'] = list(tabela.std(axis=1, ddof=0, numeric_only=True))
display(est_alunos)

# Encontrando o melhor aluno
print('*** Melhor Aluno ***')
melhor = est_alunos.loc[est_alunos['Média'] == est_alunos['Média'].max()]
display(melhor)

# Encontrando o aluno mais consistente
print('*** Aluno mais consistente ***')
consistente = est_alunos.loc[est_alunos['DesvPad'] == est_alunos['DesvPad'].min()]
display(consistente)
# Out:
#                Média    DesvPad
# Alisa      69.000000  14.352700
# Bobby      73.333333  18.624953
# Cathrine   66.333333   8.993825
# Madonna    58.000000  12.027746
# Rocky      50.333333  17.307673
# Sebastian  70.333333   6.236096
# Jaqueline  78.333333   4.784233
# Rahul      77.000000  10.708252
# David      52.333333  13.224556
# Andrew     63.666667  24.608038
# Ajay       89.000000  12.754084
# Teresa     64.666667   5.436502
# *** Melhor Aluno ***
#       Média    DesvPad
# Ajay   89.0  12.754084
# *** Aluno mais consistente ***
#                Média   DesvPad
# Jaqueline  78.333333  4.784233

# %% [markdown]
# ##Média e desvio padrão de dados agrupados##

# %%
# Colunas iniciais da distribuição de frequência
#aqui vamos contruir uma distribuição de frequência para os dados.
#A seguir, use a tabela para estimar a média e o desvio padrão amostral do conjunto de dados.
#Para isso, use 32 como o ponto médio para “30 horas ou mais".

dados = pd.DataFrame({'Classe': ['0-4', '5-9', '10-14', '15-19',
                                 '20-24', '25-29', '30 ou +'],
                      'Freq (f)': [5, 12, 24, 17, 16, 11, 5],
                      'Pt. médio (x)':[2, 7, 12, 17, 22, 27, 32]})
# Coluna valor * frequência
dados['x*f'] = dados['Freq (f)']*dados['Pt. médio (x)']
# Cálculo da média
media_dados = dados['Pt. médio (x)'].mean()
# Coluna valor - média
dados['x-xbarra'] = dados['Pt. médio (x)'] - media_dados
# Coluna (valor - média)^2
dados['(x-xbarra)^2'] = dados['x-xbarra']**2
# Coluna (valor - média)^2 * frequência
dados['(x-xbarra)^2*f'] = dados['(x-xbarra)^2']*dados['Freq (f)']
display(dados)
# Cálculo da média amostral
obs = dados['Freq (f)'].sum()
media_am = dados['x*f'].sum()/obs
print(f'Média amostral: {media_am:.1f} horas')
# Cálculo do desvio padrão amostral
desv_pam_am = (dados['(x-xbarra)^2*f'].sum()/(obs-1))**(1/2)
print(f'Desvio padrão amostral: {desv_pam_am:.1f} horas')
# Out:
#     Classe  Freq (f)  Pt. médio (x)  x*f  x-xbarra  (x-xbarra)^2  \
# 0      0-4         5              2   10     -15.0         225.0
# 1      5-9        12              7   84     -10.0         100.0
# 2    10-14        24             12  288      -5.0          25.0
# 3    15-19        17             17  289       0.0           0.0
# 4    20-24        16             22  352       5.0          25.0
# 5    25-29        11             27  297      10.0         100.0
# 6  30 ou +         5             32  160      15.0         225.0
#
#    (x-xbarra)^2*f
# 0          1125.0
# 1          1200.0
# 2           600.0
# 3             0.0
# 4           400.0
# 5          1100.0
# 6          1125.0
# Média amostral: 16.4 horas
# Desvio padrão amostral: 7.9 horas

# %% [markdown]
# ##Comparando dois conjuntos de dados##

# %%
# Conjunto de dados
salarios = pd.DataFrame({'Dallas': [41.6, 50.0, 49.5, 38.7, 39.9,
                                    45.8, 44.7, 47.8, 40.5, 44.3],
                         'New York': [45.6, 41.5, 57.6, 55.1, 59.3,
                                      59.0, 50.6, 47.2, 42.3, 51.0]})
display(salarios)

# Cálculo das médias, desvios padrão e coeficiente de variação com os seguintes codigos:
est_sal =pd.DataFrame(salarios.mean(axis=0, numeric_only=True), columns=['Média'])
est_sal['DesvPad'] = salarios.std(axis=0, ddof=0, numeric_only=True)
est_sal['CV'] = est_sal['DesvPad']/est_sal['Média']*100
display(est_sal)
# Out:
#    Dallas  New York
# 0    41.6      45.6
# 1    50.0      41.5
# 2    49.5      57.6
# 3    38.7      55.1
# 4    39.9      59.3
# 5    45.8      59.0
# 6    44.7      50.6
# 7    47.8      47.2
# 8    40.5      42.3
# 9    44.3      51.0
#           Média   DesvPad         CV
# Dallas    44.28  3.829308   8.647940
# New York  50.92  6.347409  12.465453

# %% [markdown]
# Calculando media, variancia, desvio padrao e amplitude

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Construção do conjunto de dados
#POPULACIONAL
vitorias = pd.Series([13, 10, 12, 11, 7, 8, 6, 6,
                      10, 7, 12, 4, 6, 5, 2, 2])

# %%
# Cáclulo da amplitude
amp_vit = vitorias.max() - vitorias.min()
print(f'Amplitude = {amp_vit} vitórias.')

#media
media = vitorias.mean()
print(f'a media eh {media:.1f}.')

#variancia
# Cálculo da variância populacional (ddof=0)
var_vit = vitorias.var(ddof=0)
print(f'Variância = {var_vit:.1f} vitórias^2.')


#desvio padrao
# Cálculo do desvio padrão populacional (ddof=0)
std_vit = vitorias.std(ddof=0)
print(f'Desvio padrão = {std_vit:.1f} vitórias.')
# Out:
# Amplitude = 11 vitórias.
# a media eh 7.6.
# Variância = 11.4 vitórias^2.
# Desvio padrão = 3.4 vitórias.

# %%
# Construção do conjunto de dados
#AMOSTRAL!!!
idade = pd.Series([16, 18, 19, 17, 14, 15, 17, 17,
                      17, 16, 19, 22, 24, 14, 16, 14, 18])
# Cálculo da amplitude
amp_idade = idade.max() - idade.min()
print(f'Amplitude = {amp_idade} idade.')  # Corrigiu para usar a variável correta (amp_idade).
print(amp_idade)

#media
media = idade.mean()
print(f'a media eh {media:.1f}.')


# Cálculo da variância amostral (ddof=1)
var_idade = idade.var(ddof=1)
print(f'Variância = {var_idade:.1f} idades^2.')  # Corrigiu para usar a variável correta (idade) para calcular a variância.



# Cálculo do desvio padrão amostral (ddof=1)
std_idade = idade.std(ddof=1)
print(f'Desvio padrão = {std_idade:.1f} idade.')
# Out:
# Amplitude = 10 idade.
# 10
# a media eh 17.2.
# Variância = 7.3 idades^2.
# Desvio padrão = 2.7 idade.

# %%
# Colunas iniciais da distribuição de frequência
#tinha um gráfico de piza aqui
# Construa uma distribuição de frequência para
#os dados. A seguir, use a tabela para estimar a média e o desvio padrão amostral
#do conjunto de dados. Para isso, use 32 como o ponto médio para “30 horas ou mais".
import pandas as pd
dados = pd.DataFrame({'Classe': ['0-4', '5-9', '10-14', '15-19',
                                 '20-24', '25-29', '30 ou +'],
                      'Freq (f)': [5, 12, 24, 17, 16, 11, 5],
                      'Pt. médio (x)':[2, 7, 12, 17, 22, 27, 32]})
# Coluna valor * frequência
dados['x*f'] = dados['Freq (f)']*dados['Pt. médio (x)']
# Cálculo da média
media_dados = dados['Pt. médio (x)'].mean()
# Coluna valor - média
dados['x-xbarra'] = dados['Pt. médio (x)'] - media_dados
# Coluna (valor - média)^2
dados['(x-xbarra)^2'] = dados['x-xbarra']**2
# Coluna (valor - média)^2 * frequência
dados['(x-xbarra)^2*f'] = dados['(x-xbarra)^2']*dados['Freq (f)']
display(dados)
# Cálculo da média amostral
obs = dados['Freq (f)'].sum()
media_am = dados['x*f'].sum()/obs
print(f'Média amostral: {media_am:.1f} horas')
# Cálculo do desvio padrão amostral
desv_pam_am = (dados['(x-xbarra)^2*f'].sum()/(obs-1))**(1/2)
print(f'Desvio padrão amostral: {desv_pam_am:.1f} horas')
# Out:
#     Classe  Freq (f)  Pt. médio (x)  x*f  x-xbarra  (x-xbarra)^2  \
# 0      0-4         5              2   10     -15.0         225.0
# 1      5-9        12              7   84     -10.0         100.0
# 2    10-14        24             12  288      -5.0          25.0
# 3    15-19        17             17  289       0.0           0.0
# 4    20-24        16             22  352       5.0          25.0
# 5    25-29        11             27  297      10.0         100.0
# 6  30 ou +         5             32  160      15.0         225.0
#
#    (x-xbarra)^2*f
# 0          1125.0
# 1          1200.0
# 2           600.0
# 3             0.0
# 4           400.0
# 5          1100.0
# 6          1125.0
# Média amostral: 16.4 horas
# Desvio padrão amostral: 7.9 horas

# %%
# Conjunto de dados
salarios = pd.DataFrame({'Dallas': [41.6, 50.0, 49.5, 38.7, 39.9,
                                    45.8, 44.7, 47.8, 40.5, 44.3],
                         'New York': [45.6, 41.5, 57.6, 55.1, 59.3,
                                      59.0, 50.6, 47.2, 42.3, 51.0]})
display(salarios)

# Cálculo das médias, desvios padrão e coeficiente de variação
est_sal =pd.DataFrame(salarios.mean(axis=0, numeric_only=True), columns=['Média'])
est_sal['DesvPad'] = salarios.std(axis=0, ddof=0, numeric_only=True)
est_sal['CV'] = est_sal['DesvPad']/est_sal['Média']*100
display(est_sal)
# Out:
#    Dallas  New York
# 0    41.6      45.6
# 1    50.0      41.5
# 2    49.5      57.6
# 3    38.7      55.1
# 4    39.9      59.3
# 5    45.8      59.0
# 6    44.7      50.6
# 7    47.8      47.2
# 8    40.5      42.3
# 9    44.3      51.0
#           Média   DesvPad         CV
# Dallas    44.28  3.829308   8.647940
# New York  50.92  6.347409  12.465453

# %% [markdown]
# <h1>Análise dos quartis de uma série de dados</h1>
# Para o conjunto de dados a seguir:
#
# * Determine os quartis
# * Calcule a amplitude interquartil
# * Identifique quaisquer outliers

# %%
import pandas as pd
# Conjunto de dados
dados = pd.Series([42, 53, 36, 28, 26, 41, 37, 40, 48, 45,
                   19, 38, 36, 56, 43, 34, 52, 38, 50, 43])
# Determinação dos três quartis
quartis = dados.quantile([0.25, 0.5, 0.75], interpolation='linear') #aqui já fizemos a conta para achar os quartis.
print('Quartis em um Panda Series:')
display(quartis) # É um objeto panda Series
# Mostrando os quartis ao usuário
print('Desmembrando os quartis:')
lquartis = list(quartis)
for i in range(len(lquartis)):
  print(f'Q{str(i+1)} = {lquartis[i]}')
# Calculando a amplitude interquartil
interquartil = quartis[0.75] - quartis[0.25] #aqui calculamos a amplitude interquartil. maior-menor
print(f'Amplitude interquartil: {interquartil}')
# Limites para detecção de outliers
#comletamos os dois abaixo
lim_min = quartis[0.25] - 1.5*interquartil
lim_max = quartis[0.75] + 1.5*interquartil
print('Limites de detecção para outliers:')
print(f'Inferior = {lim_min}')
print(f'Superior = {lim_max}')
# Procurando por outliers
#completamos abaixo outliers
out_inf = dados.loc[dados <= lim_min]
print('Outlier inferior:')
display(out_inf)
#completamos abaixo outliers
out_sup = dados.loc[dados >= lim_max]
print('Outlier superior:')
display(out_sup)
# Out:
# Quartis em um Panda Series:
# 0.25    36.00
# 0.50    40.50
# 0.75    45.75
# dtype: float64
# Desmembrando os quartis:
# Q1 = 36.0
# Q2 = 40.5
# Q3 = 45.75
# Amplitude interquartil: 9.75
# Limites de detecção para outliers:
# Inferior = 21.375
# Superior = 60.375
# Outlier inferior:
# 10    19
# dtype: int64
# Outlier superior:
# Series([], dtype: int64)

# %% [markdown]
# # Customizando as separatrizes
# É possível customizar as separatrizes usando o método quantile(). Basta passar uma lista com os percentis desejados.

# %%
# Determinação dos percentis customizados
#completamos abaixo os percentis com os numeros que quisemos
percentis = dados.quantile([0.1, 0.35, 0.68, 0.95], interpolation='linear')
print('Percentis em um Panda Series:')
display(percentis) # É um objeto panda Series
# Out:
# Percentis em um Panda Series:
# 0.10    27.80
# 0.35    37.65
# 0.68    43.00
# 0.95    53.15
# dtype: float64

# %% [markdown]
# <h1>Análise exploratória inicial</h1>
# O Pandas permite uma análise exploratória simplificada por meio do método describe().

# %%
# Análise exploratória
#completamos os dados abaixo com o código:
dados.describe()
# Out:
# count    20.000000
# mean     40.250000
# std       9.306902
# min      19.000000
# 25%      36.000000
# 50%      40.500000
# 75%      45.750000
# max      56.000000
# dtype: float64

# %% [markdown]
# <h1>Análise dos quartis de um painel de dados</h1>
# O estudo realizado nas séries pode ser facilmente estendido para o caso de painéis de dados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importação do conjunto de dados
#assim que pegamos dados do drive para o colab
gorjetas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/tips (1).csv')
display(gorjetas.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd  # Adicionei a importação do pandas

# Importação do conjunto de dados
gorjetas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/tips (1).csv')
print('5 primeiras linhas do conjunto de dados:')
display(gorjetas.head())

# Determinação dos quartis
#completamos abaixo com o código + os quartis
quartis = gorjetas.quantile([0.25, 0.5, 0.75], axis=0, interpolation='linear', numeric_only=True)
print('Tabela com os quartis para cada coluna numérica:')
display(quartis)

# Percentis customizados
#completamos com o código abaixo
percentis = gorjetas.quantile([0.1, 0.3, 0.8], axis=0, interpolation='linear', numeric_only=True)
print('Tabela com percentis customizados:')
display(percentis)

# Análise exploratória inicial (correção na mensagem)
print('Análise exploratória:')
#completamos abaixo
gorjetas.describe()
# Out:
# 5 primeiras linhas do conjunto de dados:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# Tabela com os quartis para cada coluna numérica:
#       total_bill     tip  size
# 0.25     13.3475  2.0000   2.0
# 0.50     17.7950  2.9000   2.0
# 0.75     24.1275  3.5625   3.0
# Tabela com percentis customizados:
#      total_bill  tip  size
# 0.1      10.340  1.5   2.0
# 0.3      14.249  2.0   2.0
# 0.8      26.098  4.0   3.0
# Análise exploratória:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# <h1>Boxplot - Série de dados</h1>
# De volta ao conjunto de dados tratado no início desse notebook:

# %%
# É preciso transformar o Pandas Series em um Pandas DataFrame
# Não há o método boxplot para Pandas Series
df = pd.DataFrame(dados)
df.boxplot(color = 'red', vert=True, whis=1.5, showmeans=True)
plt.title('Distribuição dos dados')
# Out:
# Text(0.5, 1.0, 'Distribuição dos dados')

# %% [markdown]
# <h1>Boxplot - Painéis de dados</h1>
# De volta ao conjunto de dados tips.csv. O uso do método boxplot() tem seu total potencial realizado quando os dados são um DataFrame. Vamos checar a distribuição do valor das contas por dia de funcionamento do restaurante.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Relembrando o formato dos dados
#completamos abaixo
display(gorjetas.head())
gorjetas.boxplot(by='day', column=['total_bill'], color='red', showmeans=True)
plt.title('Distribuição do valor das contas')
plt.suptitle('')
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# Text(0.5, 0.98, '')

# %%
gorjetas.boxplot(by='day', column=['tip'], color='green', showmeans=True)
plt.title('Distribuição do valor das gorjetas')
plt.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
gorjetas.boxplot(by='time', column=['tip'], color='blue', showmeans=True)
plt.title('Distribuição do valor das gorjetas')
plt.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %% [markdown]
# Também é possível agrupar a distribuição de gorjetas usando dois ou mais fatores. Aqui, vamos agrupar por dia de funcionamento e gênero do cliente.

# %%
gorjetas.boxplot(by=['day', 'sex'], column=['tip'],
                 color='blue', figsize=(12,6), showmeans=True)
plt.title('Distribuição do valor das gorjetas')
plt.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %% [markdown]
# <h1>Calculando escores-z</h1>

# %%
import scipy.stats as stats
# Criando o conjunto de dados
dados = pd.DataFrame({'Nome': ['Nik', 'Kate', 'Joe', 'Mitch', 'Alana'],
                      'Idade': [32, 30, 67, 34, 20],
                      'Renda': [80000, 90000, 45000, 23000, 12000]})
print('Tabela original:')
display(dados)
# Calculando os escores-z das colunas numéricas
#completamos a tabela abaixo
tabela_z = dados.select_dtypes(include='number').apply(stats.zscore)
print('Tabela com colunas substituídas pelos escores-z:')
display(tabela_z)
# Agregando novas colunas com os escores-z
#completamos aqui depois do = nos dois casos
dados['Escore-z Idade'] = stats.zscore(dados['Idade'])
dados['Escore-z Renda'] = stats.zscore(dados['Renda'])
print('Tabela orignal + escores-z:')
display(dados)
# Out:
# Tabela original:
#     Nome  Idade  Renda
# 0    Nik     32  80000
# 1   Kate     30  90000
# 2    Joe     67  45000
# 3  Mitch     34  23000
# 4  Alana     20  12000
# Tabela com colunas substituídas pelos escores-z:
#       Idade     Renda
# 0 -0.288493  0.978700
# 1 -0.413925  1.304934
# 2  1.906565 -0.163117
# 3 -0.163061 -0.880830
# 4 -1.041085 -1.239687
# Tabela orignal + escores-z:
#     Nome  Idade  Renda  Escore-z Idade  Escore-z Renda
# 0    Nik     32  80000       -0.288493        0.978700
# 1   Kate     30  90000       -0.413925        1.304934
# 2    Joe     67  45000        1.906565       -0.163117
# 3  Mitch     34  23000       -0.163061       -0.880830
# 4  Alana     20  12000       -1.041085       -1.239687

# %% [markdown]
# Para a distribuição a seguir, determine os respectivos quartis e construa um *boxplot* que represente o conjunto de dados (empregue a técnica de detecção de outliers fundamentada na regra

# %%
# Construção do conjunto de dados
horas_tv = pd.DataFrame([2, 4, 1, 5, 7, 2, 5, 4, 4, 2, 3, 6, 4, 3,
                      5, 2, 0, 3, 5, 9, 4, 5, 2, 1, 3, 6, 7, 2],
                        columns=['Horas TV'])
display(horas_tv.head())
# Out:
#    Horas TV
# 0         2
# 1         4
# 2         1
# 3         5
# 4         7

# %%
# Determinação dos três quartis
quartis = horas_tv.quantile([0.25, 0.5, 0.75], interpolation='linear')
display(quartis)
# Out:
#       Horas TV
# 0.25       2.0
# 0.50       4.0
# 0.75       5.0

# %%
# Construção do boxplot
horas_tv.boxplot(color='red', vert=True, whis=1.5, showmeans=True)
plt.title('Distribuição das horas em frente à TV')
plt.show()

# %% [markdown]
# *Análise:* A distribuição é assimétrica à direita e não exibe *outliers* (caso houvesse a presença de outliers, o diagrama nos mostraria, pois usamos `whis=1.5`). Os quartis revelam que:
# * $25\%$ dos entrevistados assiste até 2 horas de TV diariamente;
# * $50\%$ assistem até 4 horas diárias;
# * $75\%$ assistem até 5 horas diárias.

# %% [markdown]
# A distribuição das idades dos vencedores do *Tour de France* de 1903 a 2012, mostrada
# na tabela a seguir, tem aproximadamente a forma de sino (Fonte: *Le Tour de France*).
#
#
# A idade média é 28,1 anos, com desvio padrão de 6,4 anos.
#
# **a)** Transforme cada idade em um escore-z.
#
# **b)** Interprete os resultados.
#
# **c)** Determine se a idade de cada vencedor é incomum na distribuição.

# %%
# Construção da tabela de dados
tour = pd.DataFrame({'Vencedor': ['Bradley Wiggins', 'Jan Ulrich', 'Cadel Evans',
                                  'Henri Cornet', 'Firmin Lambot', 'Philippe Thys'],
                     'Ano': [2012, 1997, 2011, 1904, 1922, 1913],
                     'Idade': [32, 24, 34, 20, 36, 23]})
display(tour)
# Out:
#           Vencedor   Ano  Idade
# 0  Bradley Wiggins  2012     32
# 1       Jan Ulrich  1997     24
# 2      Cadel Evans  2011     34
# 3     Henri Cornet  1904     20
# 4    Firmin Lambot  1922     36
# 5    Philippe Thys  1913     23

# %%
from scipy.stats import zscore

# Item (a)
# Calculando os escores-z das colunas numéricas
tour['Z_Idade'] = zscore(tour['Idade'])
display(tour)
# Out:
#           Vencedor   Ano  Idade   Z_Idade
# 0  Bradley Wiggins  2012     32  0.631859
# 1       Jan Ulrich  1997     24 -0.686803
# 2      Cadel Evans  2011     34  0.961524
# 3     Henri Cornet  1904     20 -1.346134
# 4    Firmin Lambot  1922     36  1.291189
# 5    Philippe Thys  1913     23 -0.851635

# %% [markdown]
# *Respostas - Itens b, c:* Os escores-z estão todos na faixa de -2 a 2, logo representam valores comuns. De fato, o menor escore-z ($-1,34$) designa o mais jovem vencedor listado na tabela, Henri Cornet (20 anos) e o maior escore-z ($1,29$) representa o vencedor mais velho, Firmin Lambot, há época com 36 anos.

# %% [markdown]
# # Identificando espaços amostrais: A moeda e o dado
# Descreva o espaço amostral de um experimento probabilístico que consiste do lançamento de uma moeda seguido do lançamento de um dado de seis faces.

# %%
import itertools
# Resultados para o lançamento da moeda e do dado
moeda = ['Cara', 'Coroa']
dado = ['1', '2', '3', '4', '5', '6']
# Criação do espaço amostral
omega = [resultado for resultado in itertools.product(moeda, dado)]
# Visualização dos elementos do espaço amostral
print('** Espaço amostral **')
for resultado in omega:
  print(resultado)
# Número de elementos no espaço amostral
n_omega = len(omega)
print(f'\nExistem {n_omega} elementos no espaço amostral.')
# Out:
# ** Espaço amostral **
# ('Cara', '1')
# ('Cara', '2')
# ('Cara', '3')
# ('Cara', '4')
# ('Cara', '5')
# ('Cara', '6')
# ('Coroa', '1')
# ('Coroa', '2')
# ('Coroa', '3')
# ('Coroa', '4')
# ('Coroa', '5')
# ('Coroa', '6')
#
# Existem 12 elementos no espaço amostral.

# %% [markdown]
# # Identificando espaços amostrais: a compra do carro novo
# Você está comprando um carro novo. Os fabricantes possíveis, tamanhos dos carros e as cores estão listados a seguir:
#
#
# * Fabricantes: Ford, GM, Honda
# * Tamanhos: compacto, médio
# * Cores: branco, vermelho, preto e verde
#
# Descreva o espaço amostral que compreende todas as possíveis escolhas de compra.

# %%
# Listas de opções por atributo
fabricantes = ['Ford', 'GM', 'Honda']
tamanhos = ['Compacto', 'Médio']
cores = ['Branco', 'Vermelho', 'Preto', 'Verde']
# Criação do espaço amostral
esp_amostral = [resultado for resultado in itertools.product(fabricantes, tamanhos, cores)]
# Visualização dos elementos do espaço amostral
print('** Espaço amostral **')
for resultado in esp_amostral:
  print(resultado)
# Número de elementos no espaço amostral
elementos = len(esp_amostral)
print(f'\nExistem {elementos} elementos no espaço amostral.')
# Out:
# ** Espaço amostral **
# ('Ford', 'Compacto', 'Branco')
# ('Ford', 'Compacto', 'Vermelho')
# ('Ford', 'Compacto', 'Preto')
# ('Ford', 'Compacto', 'Verde')
# ('Ford', 'Médio', 'Branco')
# ('Ford', 'Médio', 'Vermelho')
# ('Ford', 'Médio', 'Preto')
# ('Ford', 'Médio', 'Verde')
# ('GM', 'Compacto', 'Branco')
# ('GM', 'Compacto', 'Vermelho')
# ('GM', 'Compacto', 'Preto')
# ('GM', 'Compacto', 'Verde')
# ('GM', 'Médio', 'Branco')
# ('GM', 'Médio', 'Vermelho')
# ('GM', 'Médio', 'Preto')
# ('GM', 'Médio', 'Verde')
# ('Honda', 'Compacto', 'Branco')
# ('Honda', 'Compacto', 'Vermelho')
# ('Honda', 'Compacto', 'Preto')
# ('Honda', 'Compacto', 'Verde')
# ('Honda', 'Médio', 'Branco')
# ('Honda', 'Médio', 'Vermelho')
# ('Honda', 'Médio', 'Preto')
# ('Honda', 'Médio', 'Verde')
#
# Existem 24 elementos no espaço amostral.

# %% [markdown]
# # Cálculo de probabilidades clássicas: o carro novo
# Calcule a probabilidade de que sue carro novo seja:
#
#
# *   Do fabricante Ford
# *   Da cor verde
# *   Um compacto
# *   Um compacto Honda
# *   Um GM vermelho

# %%
# Probabilidade de que o carro novo seja um Ford
evento_1 = [escolha for escolha in esp_amostral if 'Ford' in escolha]
print('** Evento 1: Carro novo é um Ford **')
for resultado in evento_1:
  print(resultado)
prob_1 = len(evento_1)/len(esp_amostral)
print(f'Probabilidade do evento 1 = {prob_1*100:.2f}%\n')
# Probabilidade de que o carro novo seja da cor verde
evento_2 = [escolha for escolha in esp_amostral if 'Verde' in escolha]
print('** Evento 2: Carro novo é da cor verde **')
for resultado in evento_2:
  print(resultado)
prob_2 = len(evento_2)/len(esp_amostral)
print(f'Probabilidade do evento 2 = {prob_2*100:.2f}%\n')
# Probabilidade de que o carro novo seja um compacto
evento_3 = [escolha for escolha in esp_amostral if 'Compacto' in escolha]
print('** Evento 3: Carro novo é um compacto **')
for resultado in evento_3:
  print(resultado)
prob_3 = len(evento_3)/len(esp_amostral)
print(f'Probabilidade do evento 3 = {prob_3*100:.2f}%\n')
# Probabilidade de que o carro novo seja um compacto Honda
evento_4 = [escolha for escolha in esp_amostral if 'Honda' in escolha if 'Compacto' in escolha]
print('** Evento 4: Carro novo é um compacto Honda **')
for resultado in evento_4:
  print(resultado)
prob_4 = len(evento_4)/len(esp_amostral)
print(f'Probabilidade do evento 4 = {prob_4*100:.2f}%\n')
# Probabilidade de que o carro novo um GM vermelho
evento_5 = [escolha for escolha in esp_amostral if 'GM' in escolha if 'Vermelho' in escolha]
print('** Evento 5: Carro novo é um GM vermelho **')
for resultado in evento_5:
  print(resultado)
prob_5 = len(evento_5)/len(esp_amostral)
print(f'Probabilidade do evento 5 = {prob_5*100:.2f}%\n')
# Out:
# ** Evento 1: Carro novo é um Ford **
# ('Ford', 'Compacto', 'Branco')
# ('Ford', 'Compacto', 'Vermelho')
# ('Ford', 'Compacto', 'Preto')
# ('Ford', 'Compacto', 'Verde')
# ('Ford', 'Médio', 'Branco')
# ('Ford', 'Médio', 'Vermelho')
# ('Ford', 'Médio', 'Preto')
# ('Ford', 'Médio', 'Verde')
# Probabilidade do evento 1 = 33.33%
#
# ** Evento 2: Carro novo é da cor verde **
# ('Ford', 'Compacto', 'Verde')
# ('Ford', 'Médio', 'Verde')
# ('GM', 'Compacto', 'Verde')
# ('GM', 'Médio', 'Verde')
# ('Honda', 'Compacto', 'Verde')
# ('Honda', 'Médio', 'Verde')
# Probabilidade do evento 2 = 25.00%
#
# ** Evento 3: Carro novo é um compacto **
# ('Ford', 'Compacto', 'Branco')
# ('Ford', 'Compacto', 'Vermelho')
# ('Ford', 'Compacto', 'Preto')
# ('Ford', 'Compacto', 'Verde')
# ('GM', 'Compacto', 'Branco')
# ('GM', 'Compacto', 'Vermelho')
# ('GM', 'Compacto', 'Preto')
# ('GM', 'Compacto', 'Verde')
# ('Honda', 'Compacto', 'Branco')
# ('Honda', 'Compacto', 'Vermelho')
# ('Honda', 'Compacto', 'Preto')
# ('Honda', 'Compacto', 'Verde')
# Probabilidade do evento 3 = 50.00%
#
# ** Evento 4: Carro novo é um compacto Honda **
# ('Honda', 'Compacto', 'Branco')
# ('Honda', 'Compacto', 'Vermelho')
# ('Honda', 'Compacto', 'Preto')
# ('Honda', 'Compacto', 'Verde')
# Probabilidade do evento 4 = 16.67%
#
# ** Evento 5: Carro novo é um GM vermelho **
# ('GM', 'Compacto', 'Vermelho')
# ('GM', 'Médio', 'Vermelho')
# Probabilidade do evento 5 = 8.33%

# %% [markdown]
# # Cálculo de probabilidades empíricas
#
# Uma empresa está conduzindo uma pesquisa por telefone com indivíduos selecionados aleatoriamente para determinar a idade dos usuários de sites de redes sociais. Até o momento, 975 usuários foram
# pesquisados. Com base na distribuição de frequência mostrada na tabela, calcule as probabilidades de que um novo indivíduo respondente da pesquisa pertença à cada faixa etária.

# %%
import pandas as pd
# DataFrame com os dados da pesquisa
pesquisa = pd.DataFrame({'Frequência': [156, 312, 254, 195, 58]})
pesquisa.index = ['18 a 22', '23 a 35', '36 a 49', '50 a 65', 'acima de 65']
display(pesquisa)
# Cálculo das probabilidades
pesquisa['Probabilidades'] = pesquisa['Frequência']/pesquisa['Frequência'].sum()*100
display(pesquisa)
# Out:
#              Frequência
# 18 a 22             156
# 23 a 35             312
# 36 a 49             254
# 50 a 65             195
# acima de 65          58
#              Frequência  Probabilidades
# 18 a 22             156       16.000000
# 23 a 35             312       32.000000
# 36 a 49             254       26.051282
# 50 a 65             195       20.000000
# acima de 65          58        5.948718

# %% [markdown]
# # A lei dos grandes núeros em ação
#
# Se uma moeda é não-viesada, as probabilidades de cara ou coroa em um lançamento são iguais. Assim, na medida em que o núemro de lançamentos cresce, a probabilidade empírica (frequência relativa) deve se aproximar da probabilidade real de 50%.
#
# O código abaixo simula 100 experimentos com um número de lançamentos que varia de 1 a 5000.A representação gráfica mostra a evolução das proporções de "cara" em cada um dos experimentos.

# %%
import random
import matplotlib.pyplot as plt

# Função para lançamentos da moeda
def moeda(lancamentos):
  cara = 0
  for _ in range(lancamentos):
    if random.random() <= 0.5:
        cara +=1
  return cara/lancamentos

# Função para geração de cada experimento
def experimentos(lista_lancamentos):
    proporcoes = []
    for n_lancamento in lista_lancamentos:
        proporcoes.append(moeda(n_lancamento))
    return proporcoes

# Simulação
testes = list(range(1,5000,50))
resultados = experimentos(testes)
# Representação gráfica
plt.scatter(testes, resultados)
plt.title('Probailidade de se obter "cara"')
plt.xlabel('Número de lançamentos')
plt.ylabel('Proporção de caras')
plt.grid()

# %% [markdown]
# # Probabilidades condicionais - Esportes
# O conjunto de dados a seguir relaciona os esportes preferidos de 300 pessoas. Execute o código e inspecione algumas linhas do DataFrame.

# %%
import pandas as pd
import numpy as np

# Criação do pandas DataFrame
esportes = pd.DataFrame({'gênero': np.repeat(np.array(['Masculino', 'Feminino']), 150),
                         'esporte': np.repeat(np.array(['Beisebol', 'Basquete',
                                                        'Futebol', 'Vôlei',
                                                        'Beisebol', 'Basquete',
                                                        'Futebol', 'Vôlei']),
                                              (34, 40, 58, 18, 34, 52, 20, 44))})
# Inspeção de algumas linhas do painel de dados
display(esportes.head())
display(esportes.tail())
# Out:
#       gênero   esporte
# 0  Masculino  Beisebol
# 1  Masculino  Beisebol
# 2  Masculino  Beisebol
# 3  Masculino  Beisebol
# 4  Masculino  Beisebol
#        gênero esporte
# 295  Feminino   Vôlei
# 296  Feminino   Vôlei
# 297  Feminino   Vôlei
# 298  Feminino   Vôlei
# 299  Feminino   Vôlei

# %% [markdown]
# ## Tabela de distribuição conjunta de frequências
# O cálculo de probabiidades condicionais fica facilitado a partir de uma tabela de distribuição conjunta de frequências. No caso desse exemplo, a tabela indicará as ocorrências de cada esporte em função do gênero do entrevistado. As colunas e linhas de rótulo "All" revelam os totais de ocorrências.

# %%
# Construção da tabela de distrbuição conjunta
dist_conj = pd.crosstab(index=esportes['gênero'],
                        columns=esportes['esporte'], margins=True)
# Inspeção da tabela de distribuição conjunta
display(dist_conj)
# Out:
# esporte    Basquete  Beisebol  Futebol  Vôlei  All
# gênero
# Feminino         52        34       20     44  150
# Masculino        40        34       58     18  150
# All              92        68       78     62  300

# %% [markdown]
# ## Cálculo de probabilidades condicionais
# Use a tabela de distribuição conjunta da cálula anterior e calcule a probabilidade de que um indivíduo sorteado aleatoriamente:
#
# *   seja do gênero masculino, visto que seu esporte preferido é o beisebol.
# *   tenha por esporte preferido o basquete, dado que seja do gênero feminino.
#
# No cáclulo dessas probabilidades, use o método iloc do pandas DataFrame para localizar a informação desejada em termos das coordenadas de linha e coluna da tabela de distribuição conjunta.

# %%
# Probabilidade de ser do gênero masculino, dado que é fã de beisebol
prob = dist_conj.iloc[1, 1] / dist_conj.iloc[2, 1]
print(f'P(Masculino|Beisebol) = {prob*100:.2f}%')

# Probabilidade de ser fã de basquete, dado que é do gênero feminino
prob = dist_conj.iloc[0, 0] / dist_conj.iloc[0, 4]
print(f'P(Basquete|Feminino) = {prob*100:.2f}%')
# Out:
# P(Masculino|Beisebol) = 50.00%
# P(Basquete|Feminino) = 34.67%

# %% [markdown]
# ## Distribuição conjunta normalizada pelas colunas
#
# Para determinar todas as probabilidades condicionais do tipo P(Gênero|Esporte), basta normalizar a tabela de distribuição conjunta usando as colunas.

# %%
''' Tabela de distribuição conjunta normalizada pelas colunas: Em nosso exemplo,
exibe todas as probabilidades condicionais do tipo P(Gênero|Esporte)'''
dist_conj_colunas = pd.crosstab(index=esportes['gênero'],
                                columns=esportes['esporte'],
                                margins=True, normalize='columns')
# Inspeção da tabela
display(dist_conj_colunas)
# Out:
# esporte    Basquete  Beisebol  Futebol     Vôlei  All
# gênero
# Feminino   0.565217       0.5  0.25641  0.709677  0.5
# Masculino  0.434783       0.5  0.74359  0.290323  0.5

# %% [markdown]
# ## Distribuição conjunta normalizada pelas linhas (índice)
#
# Em contraste, para determinar todas as probabilidades condicionais do tipo P(Esporte|Gênero), basta normalizar a tabela de distribuição conjunta usando as linhas (ou seja, os índices).

# %%
''' Tabela de distribuição conjunta normalizada pelas linhas: Em nosso exemplo,
exibe todas as probabilidades condicionais do tipo P(Esporte|Gênero)'''
dist_conj_linhas = pd.crosstab(index=esportes['gênero'],
                               columns=esportes['esporte'],
                               margins=True, normalize='index')
# Inspeção da tabela
display(dist_conj_linhas)
# Out:
# esporte    Basquete  Beisebol   Futebol     Vôlei
# gênero
# Feminino   0.346667  0.226667  0.133333  0.293333
# Masculino  0.266667  0.226667  0.386667  0.120000
# All        0.306667  0.226667  0.260000  0.206667

# %% [markdown]
# # Probabilidades condicionais - automóveis
# O conjunto de dados a seguir reune informações sobre a montadora, o modelo, o tipo e a classificação (nota atribuída por imprensa qualificada) de alguns automóveis.

# %%
# Construção do conjunto de dados
auto = pd.DataFrame({'montadora': ['ford', 'chevy', 'ford',
                                   'ford', 'ford', 'toyota'],
                     'modelo': ['mustang', 'camaro', 'fiesta',
                                'focus', 'taurus', 'camry'],
                     'nota': ['A', 'B', 'C', 'A', 'B', 'B'],
                     'tipo': ['coupe', 'coupe', 'sedan',
                              'sedan', 'sedan', 'sedan']})
# Inspeção da tabela
display(auto)
# Out:
#   montadora   modelo nota   tipo
# 0      ford  mustang    A  coupe
# 1     chevy   camaro    B  coupe
# 2      ford   fiesta    C  sedan
# 3      ford    focus    A  sedan
# 4      ford   taurus    B  sedan
# 5    toyota    camry    B  sedan

# %% [markdown]
# Construa a tabela de distrbuição conjunta de frequências usando o tipo do automóvel como indexador de linhas e as respectivas notas como colunas. A seguir, calcule a probabilidade de um automóvel:
#
# *   ser classificado com nota A, dado que é do tipo sedan.
# *   ser do tipo coupe, dado que foi avaliado com nota B.

# %%
# Construção da tabela de distribuição conjunta
tabela = pd.crosstab(auto.tipo, auto.nota, margins=True)
# Inspeção da tabela
display(tabela)
# Cálculo das probabilidades
prob1 = tabela.iloc[1, 0] / tabela.iloc[1, 3]
print(f'P(A|sedan) = {prob1*100:.2f}%')
prob2 = tabela.iloc[0, 1] / tabela.iloc[2, 1]
print(f'P(coupe|B) = {prob2*100:.2f}%')
# Out:
# nota   A  B  C  All
# tipo
# coupe  1  1  0    2
# sedan  1  2  1    4
# All    2  3  1    6
# P(A|sedan) = 25.00%
# P(coupe|B) = 33.33%

# %% [markdown]
# Verifique seus cálculos ao construir versões da tabela de distribuição conjunta normalizadas pelas colunas e linhas.

# %%
# Probabilidades condicionais: P(nota|tipo)
print('** Probabilidades condicionais: P(nota|tipo) **')
tabela_linhas = pd.crosstab(auto.tipo, auto.nota,
                            margins=True, normalize="index")
display(tabela_linhas)
# Probabilidades condicionais: P(tipo|nota)
print('** Probabilidades condicionais: P(tipo|nota) **')
tabela_colunas = pd.crosstab(auto.tipo, auto.nota,
                             margins=True, normalize="columns")
display(tabela_colunas)
# Out:
# ** Probabilidades condicionais: P(nota|tipo) **
# nota          A    B         C
# tipo
# coupe  0.500000  0.5  0.000000
# sedan  0.250000  0.5  0.250000
# All    0.333333  0.5  0.166667
# ** Probabilidades condicionais: P(tipo|nota) **
# nota     A         B    C       All
# tipo
# coupe  0.5  0.333333  0.0  0.333333
# sedan  0.5  0.666667  1.0  0.666667

# %% [markdown]
# # **TTI109 - Estatística**
# # **Aula 09 - Distribuições Discretas de Probabilidade 01**
#
# Nessa aula vamos aprender a:
#
# * Identificar variáveis aleatórias discretas;
# * Construir uma distribuição discreta de probabilidades para uma variável aleatória (discreta);
# * Calcular a média, a variância e o desvio padrão de uma distribuição discreta de probabilidades.

# %% [markdown]
# ## Distribuição discreta de probabilidades
# Uma empresa rastreia o número de vendas que os novos colaboradores
# fazem todos os dias, durante um período de experiência de 100 dias. Os
# resultados de um novo colaborador estão indicados na tabela a seguir.
#
#
# Organize as probabilidades em uma distribuição de probabilidade.
# Represente graficamente a distribuição de probabilidades e a probabilidade acumulada.

# %%
# Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Conjunto de dados
tabela = pd.DataFrame({'Vendas/dia': list(range(8)),
                       'Num_dias': [16, 19, 15, 21, 9, 10, 8, 2]})
display(tabela)
# Out:
#    Vendas/dia  Num_dias
# 0           0        16
# 1           1        19
# 2           2        15
# 3           3        21
# 4           4         9
# 5           5        10
# 6           6         8
# 7           7         2

# %%
# Cálculo das probabilidades
total_vendas = tabela['Num_dias'].sum()
tabela['P(x)'] = tabela['Num_dias']/total_vendas
display(tabela)
# Out:
#    Vendas/dia  Num_dias  P(x)
# 0           0        16  0.16
# 1           1        19  0.19
# 2           2        15  0.15
# 3           3        21  0.21
# 4           4         9  0.09
# 5           5        10  0.10
# 6           6         8  0.08
# 7           7         2  0.02

# %%
# Cálculo da probabilidade acumulada
tabela['P_ac(x)'] = tabela['P(x)'].cumsum()
display(tabela)
# Out:
#    Vendas/dia  Num_dias  P(x)  P_ac(x)
# 0           0        16  0.16     0.16
# 1           1        19  0.19     0.35
# 2           2        15  0.15     0.50
# 3           3        21  0.21     0.71
# 4           4         9  0.09     0.80
# 5           5        10  0.10     0.90
# 6           6         8  0.08     0.98
# 7           7         2  0.02     1.00

# %% [markdown]
# ## Representação gráfica da distribuição discreta de probabilidades

# %%
# Gráfico de segmentos verticais (caules)
plt.stem(tabela['Vendas/dia'], tabela['P(x)'], linefmt='b-',
         label='P(efetuar x vendas ao dia)')
plt.xlabel('Vendas por dia')
plt.ylabel('Probabilidades')
plt.title('Distribuição discreta de probabilidades')
plt.grid()
plt.legend()
plt.show()

# %%
# Gráfico de barras verticais
plt.bar(tabela['Vendas/dia'], tabela['P(x)'],
        label='P(efetuar x vendas ao dia)')
plt.xlabel('Vendas por dia')
plt.ylabel('Probabilidades')
plt.title('Distribuição discreta de probabilidades')
plt.grid(False)
plt.legend()
plt.show()

# %%
# Representação gráfica da probabilidade discreta acumulada
plt.plot(tabela['Vendas/dia'], tabela['P_ac(x)'], 'g-o',
         label='P(efetuar x vendas ao dia) [acumulada)]')
plt.xlabel('Vendas por dia')
plt.ylabel('Probabilidades')
plt.title('Probabilidade discreta acumulada')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <h1>Média de uma distribuição discreta de probabilidades</h1>
# Calcule a média da distribuição estudada no item anterior.

# %%
# Inserção da coluna Vendas*Probabilidades
tabela['xP(x)'] = tabela['Vendas/dia']*tabela['P(x)']
display(tabela)
# Out:
#    Vendas/dia  Num_dias  P(x)  P_ac(x)  xP(x)
# 0           0        16  0.16     0.16   0.00
# 1           1        19  0.19     0.35   0.19
# 2           2        15  0.15     0.50   0.30
# 3           3        21  0.21     0.71   0.63
# 4           4         9  0.09     0.80   0.36
# 5           5        10  0.10     0.90   0.50
# 6           6         8  0.08     0.98   0.48
# 7           7         2  0.02     1.00   0.14

# %%
# Cálculo da média da distribuição
media = tabela['xP(x)'].sum()
print(f'A média da distribuição é de {media:.1f} vendas/dia.')
# Out:
# A média da distribuição é de 2.6 vendas/dia.

# %% [markdown]
# # Variância e desvio padrão de uma distribuição discreta de probabilidades
# Calcule a variância e o desvio padrão da distribuição estudada nos itens anteriores.

# %%
# Inserção da coluna Vendas^2*Probabilidades
tabela['x^2P(x)'] = tabela['Vendas/dia']**2 * tabela['P(x)']
display(tabela)
# Out:
#    Vendas/dia  Num_dias  P(x)  P_ac(x)  xP(x)  x^2P(x)
# 0           0        16  0.16     0.16   0.00     0.00
# 1           1        19  0.19     0.35   0.19     0.19
# 2           2        15  0.15     0.50   0.30     0.60
# 3           3        21  0.21     0.71   0.63     1.89
# 4           4         9  0.09     0.80   0.36     1.44
# 5           5        10  0.10     0.90   0.50     2.50
# 6           6         8  0.08     0.98   0.48     2.88
# 7           7         2  0.02     1.00   0.14     0.98

# %%
# Cálculo da variância da distribuição
variancia = tabela['x^2P(x)'].sum() - media**2
print(f'A variância da distribuição é de {variancia:.1f} (vendas/dia)^2.')
# Out:
# A variância da distribuição é de 3.7 (vendas/dia)^2.

# %%
# Cálculo do desvio padrão da distribuição
desvio = variancia**(1/2)
print(f'O desvio padrão da distribuição é de {desvio:.1f} vendas/dia.')
# Out:
# O desvio padrão da distribuição é de 1.9 vendas/dia.

# %% [markdown]
# ## Calculando algumas probabilidades
#
# Usando a distribuição de probabilidades construída anteriormente calcule a probabilidade de que um vendedor iniciante efetue:
#
# * exatamente 4 vendas em um único dia;
# * menos de 4 vendas em um único dia;
# * mais de 4 vendas em um único dia.

# %%
# Revendo a distribuição de probabilidades
display(tabela)
# Out:
#    Vendas/dia  Num_dias  P(x)  P_ac(x)  xP(x)  x^2P(x)
# 0           0        16  0.16     0.16   0.00     0.00
# 1           1        19  0.19     0.35   0.19     0.19
# 2           2        15  0.15     0.50   0.30     0.60
# 3           3        21  0.21     0.71   0.63     1.89
# 4           4         9  0.09     0.80   0.36     1.44
# 5           5        10  0.10     0.90   0.50     2.50
# 6           6         8  0.08     0.98   0.48     2.88
# 7           7         2  0.02     1.00   0.14     0.98

# %%
# P(4 vendas em um único dia)
tab_filtrada = tabela['P(x)'].loc[tabela['Vendas/dia'] == 4]
print(tab_filtrada)
prob = tab_filtrada.values[0]
print(f'P(4 vendas em um único dia) = {prob*100:.1f}%')
# Out:
# 4    0.09
# Name: P(x), dtype: float64
# P(4 vendas em um único dia) = 9.0%

# %%
# P(menos de 4 vendas em um único dia)
tab_filtrada = tabela['P(x)'].loc[tabela['Vendas/dia'] < 4]
print(tab_filtrada)
prob = tab_filtrada.sum()
print(f'P(menos de 4 vendas em um único dia) = {prob*100:.1f}%')
# Out:
# 0    0.16
# 1    0.19
# 2    0.15
# 3    0.21
# Name: P(x), dtype: float64
# P(menos de 4 vendas em um único dia) = 71.0%

# %%
# P(mais de 4 vendas em um único dia)
tab_filtrada = tabela['P(x)'].loc[tabela['Vendas/dia'] > 4]
print(tab_filtrada)
prob = tab_filtrada.sum()
print(f'P(mais de 4 vendas em um único dia) = {prob*100:.1f}%')
# Out:
# 5    0.10
# 6    0.08
# 7    0.02
# Name: P(x), dtype: float64
# P(mais de 4 vendas em um único dia) = 20.0%

# %% [markdown]
# # Distribuição de Probabilidade Binomial
# Em uma pesquisa, indivíduos adultos foram solicitados para que indicassem quais dispositivos utilizavam para acessar mídias sociais. Os resultados estão na figura.
#
# ![Aula 10-01.png](data:image/png;base64,...)
#
# Sete adultos que participaram da pesquisa são selecionados aleatoriamente e indagados se utilizam um
# telefone celular para acessar mídia social. Construa uma distribuição de probabilidade binomial para o número de adultos que respondeu sim. A seguir, represente graficamente essa distrbuição usando gráficos de segmentos e barras verticais.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import binom

# Condições do experimento probabilístico binomial
exp = 7
sucesso = 0.46
val_x = list(range(exp + 1))
# Geração da tabela de distribuição de probabilidade binomial
dist_binomial = pd.DataFrame({'Sucessos': val_x})
dist_binomial['Probabilidade'] = binom.pmf(val_x, exp, sucesso)
display(dist_binomial)
# Representação gráfica da distribuição discreta de probabilidades
# Gráfico de segmentos verticais (caules)
print('** Gráfico de segmentos verticais (caules) **')
dist_stem = plt.stem(dist_binomial['Sucessos'],
                     dist_binomial['Probabilidade'], use_line_collection=True)
plt.xlabel('Indivíduos que usam o celular para acessar redes sociais')
plt.ylabel('Probabilidades')
plt.title('Distribuição discreta de probabilidades')
plt.grid()
plt.show()
# Gráfico de barras verticais
print('** Gráfico de barras verticais **')
dist_bar = plt.bar(dist_binomial['Sucessos'],
                   dist_binomial['Probabilidade'])
plt.xlabel('Indivíduos que usam o celular para acessar redes sociais')
plt.ylabel('Probabilidades')
plt.title('Distribuição discreta de probabilidades')
plt.grid(False)
plt.show()
# Out:
#    Sucessos  Probabilidade
# 0         0       0.013389
# 1         1       0.079840
# 2         2       0.204035
# 3         3       0.289679
# 4         4       0.246763
# 5         5       0.126123
# 6         6       0.035813
# 7         7       0.004358
# ** Gráfico de segmentos verticais (caules) **
# <ipython-input-28-c01b5e972ac1>:16: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   dist_stem = plt.stem(dist_binomial['Sucessos'],
# ** Gráfico de barras verticais **

# %% [markdown]
# # Parâmetros populacionais de uma distribuição binomial
# Calcule a média, a variância e o desvio padrão da distribuição binomial do item anterior.

# %%
# ** Cálculo dos parâmetros usando as fórmulas **
# Cálculo da média (mu = np)
media = exp*sucesso
# Cálculo da variância (sigma^2 = np(1-p))
variancia = exp*sucesso*(1-sucesso)
# Cálculo do desvio padrão
desv_pad = variancia**(1/2)
# Exibição dos resultados
print('** Parâmetros populacionais - Fórmulas **')
print(f'Média = {media:.2f} indivíduos')
print(f'Variância = {variancia:.2f} indivíduos^2')
print(f'Desvio padrão = {desv_pad:.2f} indivíduos')
# Cálculo dos parâmetros usando o método stats de binom
med, var = binom.stats(exp, sucesso)
print('** Parâmetros populacionais - stats **')
print(f'Média = {med:.2f} ; Variância = {var:.2f}')
# Out:
# ** Parâmetros populacionais - Fórmulas **
# Média = 3.22 indivíduos
# Variância = 1.74 indivíduos^2
# Desvio padrão = 1.32 indivíduos
# ** Parâmetros populacionais - stats **
# Média = 3.22 ; Variância = 1.74

# %% [markdown]
# # Mais probabilidades binomiais
# Uma pesquisa com adultos americanos descobriu que 62% das mulheres acreditam que há uma ligação entre jogos violentos e adolescentes que apresentam comportamento violento. Você seleciona aleatoriamente
# quatro mulheres americanas e pergunta se elas acreditam nessa ligação entre jogos e comportamento violentos. Encontre a probabilidade de que:
#
#
# *   exatamente duas mulheres respondam sim
# *   ao menos duas mulheres respondam sim
# *   menos de duas mulheres responderam sim

# %%
# Condições do experimento probabilístico binomial
exp = 4
sucesso = 0.62
val_x = list(range(exp + 1))
# Geração da tabela de distribuição de probabilidade binomial
dist_binomial = pd.DataFrame({'Sucessos': val_x})
dist_binomial['Probabilidade'] = binom.pmf(val_x, exp, sucesso)
display(dist_binomial)
# Cálculo das probabilidades
# prob1 = prob. exatamente duas mulheres respondam sim (x=2)
prob1 = dist_binomial['Probabilidade'][2]
print(f'A probabilidade de que exatamente duas mulheres respondam sim é {prob1:.3f}')
# prob2 = prob. ao menos duas mulheres respondam sim (x>=2)
critério = dist_binomial['Sucessos'] >= 2
prob2 = dist_binomial['Probabilidade'].loc[critério].sum()
print(f'A probabilidade de que ao menos duas mulheres respondam sim é {prob2:.3f}')
# prob3 = prob. menos de duas mulheres respondam sim (x<2)
critério = dist_binomial['Sucessos'] < 2
prob3 = dist_binomial['Probabilidade'].loc[critério].sum()
print(f'A probabilidade de que menos de duas mulheres respondam sim é {prob3:.3f}')
# IMPORTANTE: note que o complemento de “x é pelo menos 2” é
# “x é menos que 2”. Logo: P(x<2) = 1-P(x>=2) = 1-0.843 = 0.157'''
# Out:
#    Sucessos  Probabilidade
# 0         0       0.020851
# 1         1       0.136083
# 2         2       0.333044
# 3         3       0.362259
# 4         4       0.147763
# A probabilidade de que exatamente duas mulheres respondam sim é 0.333
# A probabilidade de que ao menos duas mulheres respondam sim é 0.843
# A probabilidade de que menos de duas mulheres respondam sim é 0.157

# %% [markdown]
# Permutações de n objetos

# %%
from itertools import permutations, combinations
from random import choices

# Chave para permutação
chave = 'Python'

# Gerção de todas as permutações possíveis
perm_chave = permutations(chave)

# Exibição de 20 permutações sorteadas aleatoriamente
lista_perm = list(perm_chave)
print(f'São possíveis {len(lista_perm)} permutações para os caracteres de "{chave}".')
print('Seguem 20 permutações sorteadas aleatoriamente:')
sorteio = choices(lista_perm, k=20)
for caso in sorteio:
  print(caso)
# Out:
# São possíveis 720 permutações para os caracteres de "Python".
# Seguem 20 permutações sorteadas aleatoriamente:
# ('P', 't', 'h', 'y', 'n', 'o')
# ('h', 't', 'o', 'P', 'y', 'n')
# ('o', 'P', 't', 'y', 'h', 'n')
# ('o', 'P', 'y', 'h', 'n', 't')
# ('h', 'y', 't', 'o', 'P', 'n')
# ('P', 'o', 't', 'n', 'h', 'y')
# ('t', 'o', 'n', 'h', 'y', 'P')
# ('y', 'P', 'n', 't', 'h', 'o')
# ('n', 'P', 'y', 'h', 'o', 't')
# ('n', 'P', 'y', 'o', 'h', 't')
# ('y', 'o', 't', 'h', 'P', 'n')
# ('P', 'n', 'y', 'o', 't', 'h')
# ('h', 'P', 't', 'o', 'n', 'y')
# ('n', 'o', 'h', 'y', 't', 'P')
# ('y', 'n', 'h', 'P', 't', 'o')
# ('n', 'P', 'y', 't', 'o', 'h')
# ('y', 'o', 'n', 't', 'P', 'h')
# ('y', 'n', 'P', 't', 'o', 'h')
# ('y', 'h', 'P', 'o', 'n', 't')
# ('P', 'o', 'n', 'y', 't', 'h')

# %% [markdown]
# # Permutações distintas de *n* objetos
# Quando há repetição nos elementos da chave de permutação (que sempre deve ser um iterável), haverá também permutações iguais. Se desejarmos apenas as permutações distintas, é preciso usar a função `distinct_permutations` do módulo `more_itertools`.

# %%
from more_itertools import distinct_permutations

# Chave para permutação
chave = 'Geek'

# Geração de todas as permutações possíveis
todas_perm = list(permutations(chave))

# Exibição de todas as permutações
print(f'Existem {len(todas_perm)} permutações possíveis para "Geek".')
for i in range(6):
  print(todas_perm[i*4:i*4+4])
# Out:
# Existem 24 permutações possíveis para "Geek".
# [('G', 'e', 'e', 'k'), ('G', 'e', 'k', 'e'), ('G', 'e', 'e', 'k'), ('G', 'e', 'k', 'e')]
# [('G', 'k', 'e', 'e'), ('G', 'k', 'e', 'e'), ('e', 'G', 'e', 'k'), ('e', 'G', 'k', 'e')]
# [('e', 'e', 'G', 'k'), ('e', 'e', 'k', 'G'), ('e', 'k', 'G', 'e'), ('e', 'k', 'e', 'G')]
# [('e', 'G', 'e', 'k'), ('e', 'G', 'k', 'e'), ('e', 'e', 'G', 'k'), ('e', 'e', 'k', 'G')]
# [('e', 'k', 'G', 'e'), ('e', 'k', 'e', 'G'), ('k', 'G', 'e', 'e'), ('k', 'G', 'e', 'e')]
# [('k', 'e', 'G', 'e'), ('k', 'e', 'e', 'G'), ('k', 'e', 'G', 'e'), ('k', 'e', 'e', 'G')]

# %%
# Geração das permutações distintas
perm_dist = list(distinct_permutations(chave))

# Exibição das permutações distintas
print(f'Existem {len(perm_dist)} permutações distintas possíveis para "Geek".')
for i in range(3):
  print(perm_dist[i*4:i*4+4])
# Out:
# Existem 12 permutações distintas possíveis para "Geek".
# [('G', 'e', 'e', 'k'), ('G', 'e', 'k', 'e'), ('G', 'k', 'e', 'e'), ('e', 'G', 'e', 'k')]
# [('e', 'G', 'k', 'e'), ('e', 'e', 'G', 'k'), ('e', 'e', 'k', 'G'), ('e', 'k', 'G', 'e')]
# [('e', 'k', 'e', 'G'), ('k', 'G', 'e', 'e'), ('k', 'e', 'G', 'e'), ('k', 'e', 'e', 'G')]

# %% [markdown]
# Arranjo de n objetos tomados r a r

# %%
# Chave para permutação
chave = ['BRA', 'CHI', 'CAN', 'USA', 'ARG']

# Geração dos arranjos dos 5 objetos de chave, tomados 3 a 3
perm_chave = list(permutations(chave, 3))

# Exibição dos arranjos, tomados 3 a 3
print(f'Há {len(perm_chave)} elementos nos arranjos de {chave}, tomados 3 a 3.')
for i in range(15):
  print(perm_chave[i*4:i*4+4])
# Out:
# Há 60 elementos nos arranjos de ['BRA', 'CHI', 'CAN', 'USA', 'ARG'], tomados 3 a 3.
# [('BRA', 'CHI', 'CAN'), ('BRA', 'CHI', 'USA'), ('BRA', 'CHI', 'ARG'), ('BRA', 'CAN', 'CHI')]
# [('BRA', 'CAN', 'USA'), ('BRA', 'CAN', 'ARG'), ('BRA', 'USA', 'CHI'), ('BRA', 'USA', 'CAN')]
# [('BRA', 'USA', 'ARG'), ('BRA', 'ARG', 'CHI'), ('BRA', 'ARG', 'CAN'), ('BRA', 'ARG', 'USA')]
# [('CHI', 'BRA', 'CAN'), ('CHI', 'BRA', 'USA'), ('CHI', 'BRA', 'ARG'), ('CHI', 'CAN', 'BRA')]
# [('CHI', 'CAN', 'USA'), ('CHI', 'CAN', 'ARG'), ('CHI', 'USA', 'BRA'), ('CHI', 'USA', 'CAN')]
# [('CHI', 'USA', 'ARG'), ('CHI', 'ARG', 'BRA'), ('CHI', 'ARG', 'CAN'), ('CHI', 'ARG', 'USA')]
# [('CAN', 'BRA', 'CHI'), ('CAN', 'BRA', 'USA'), ('CAN', 'BRA', 'ARG'), ('CAN', 'CHI', 'BRA')]
# [('CAN', 'CHI', 'USA'), ('CAN', 'CHI', 'ARG'), ('CAN', 'USA', 'BRA'), ('CAN', 'USA', 'CHI')]
# [('CAN', 'USA', 'ARG'), ('CAN', 'ARG', 'BRA'), ('CAN', 'ARG', 'CHI'), ('CAN', 'ARG', 'USA')]
# [('USA', 'BRA', 'CHI'), ('USA', 'BRA', 'CAN'), ('USA', 'BRA', 'ARG'), ('USA', 'CHI', 'BRA')]
# [('USA', 'CHI', 'CAN'), ('USA', 'CHI', 'ARG'), ('USA', 'CAN', 'BRA'), ('USA', 'CAN', 'CHI')]
# [('USA', 'CAN', 'ARG'), ('USA', 'ARG', 'BRA'), ('USA', 'ARG', 'CHI'), ('USA', 'ARG', 'CAN')]
# [('ARG', 'BRA', 'CHI'), ('ARG', 'BRA', 'CAN'), ('ARG', 'BRA', 'USA'), ('ARG', 'CHI', 'BRA')]
# [('ARG', 'CHI', 'CAN'), ('ARG', 'CHI', 'USA'), ('ARG', 'CAN', 'BRA'), ('ARG', 'CAN', 'CHI')]
# [('ARG', 'CAN', 'USA'), ('ARG', 'USA', 'BRA'), ('ARG', 'USA', 'CHI'), ('ARG', 'USA', 'CAN')]

# %% [markdown]
# # Combinações de *n* objetos, tomados *r* a *r*
# Se a ordem de cada permutação não for importante (ABC é o mesmo que BAC, por exemplo), o número de maneiras de selecionar *r* dos *n* objetos sem levar em consideração a ordem é chamada de combinação de *n* objetos tomados *r* a *r*.

# %%
# Geração das combinações dos 5 objetos de chave, tomados 3 a 3
comb_chave = (list(combinations(chave, 3)))

# Exibição das combinações, tomadas 3 a 3
print(f'Há {len(comb_chave)} elementos nas combinações de {chave}, tomadas 3 a 3.')
for i in range(5):
  print(comb_chave[i*2:i*2+2])
# Out:
# Há 10 elementos nas combinações de ['BRA', 'CHI', 'CAN', 'USA', 'ARG'], tomadas 3 a 3.
# [('BRA', 'CHI', 'CAN'), ('BRA', 'CHI', 'USA')]
# [('BRA', 'CHI', 'ARG'), ('BRA', 'CAN', 'USA')]
# [('BRA', 'CAN', 'ARG'), ('BRA', 'USA', 'ARG')]
# [('CHI', 'CAN', 'USA'), ('CHI', 'CAN', 'ARG')]
# [('CHI', 'USA', 'ARG'), ('CAN', 'USA', 'ARG')]

# %% [markdown]
# O Pandas é uma das principais bibliotecas para exploração e entendimento dos dados.
#
# A seguir, estão os principais e mais utilizados recursos:
#
# <br>
#
# 1. **Importação dos Dados**
#
# Primeiro, importe o conjunto de dados usando pandas. O pandas é uma biblioteca Python que fornece estruturas de dados e ferramentas de análise de dados de alto desempenho.
#
# `import pandas as pd`
#
# `df = pd.read_csv('covid_dataset.csv')  # Substitua com o nome correto do seu arquivo`
#
# <br>
#
# 2. **Exploração Inicial dos Dados**
#
# Confira as primeiras e últimas linhas do dataframe para ter uma ideia inicial dos dados.
#
# `df.head()  # Visualiza as primeiras linhas do dataframe`
#
# `df.tail()  # Visualiza as últimas linhas do dataframe`
#
#
# Verifique a estrutura do dataframe:
#
# `df.info()`
#
#
# E faça um resumo estatístico dos dados numéricos:
#
# `df.describe()`
#
# Faça um contagem dos valores ausentes:
#
# `df.isna.sum()`
#
# <br>
#
# 3. **Limpeza de Dados**
#
# Limpe os dados, se necessário. Isso pode incluir o tratamento de valores nulos, remoção de colunas desnecessárias, e assim por diante.
#
# `df = df.dropna()  # Remove linhas com valores nulos
# df = df.drop(columns=['column_to_drop'])  # Remove colunas desnecessárias`
#
# <br>
#
# 4. **Análise dos Dados**
#
# Agora, você pode começar a analisar os dados. A natureza exata desta análise dependerá do seu conjunto de dados, mas algumas coisas que você pode fazer incluem:
#
# * Visualizar a distribuição de casos confirmados e mortes usando histogramas e boxplots.
# * Comparar a taxa de casos confirmados e mortes entre diferentes países ou estados.
# Observar a tendência de casos e mortes ao longo do tempo.
#
# Por exemplo, você pode querer visualizar a distribuição de casos confirmados usando um histograma:
#
# `import matplotlib.pyplot as plt`
#
# `plt.hist(df['confirmed_cases'], bins=30)`
#
# `plt.title('Distribuição de Casos Confirmados')`
#
# `plt.xlabel('Casos Confirmados')`
#
# `plt.ylabel('Frequência')`
#
# `plt.show()`
#
# <br>
#
# 5. **Análise de Correlação**
#
# Examine a correlação entre diferentes variáveis. Por exemplo, você pode estar interessado na correlação entre casos confirmados e mortes.
#
# `correlation = df['confirmed_cases'].corr(df['deaths'])`
#
# <br>
#
# Com esse resultado, pode-se plotar um gráfico chamado heatmap:
#
# `df = pd.DataFrame(dados)`
#
# `# Calcule a matriz de correlação`
#
# `corr_matrix = df.corr()`
#
# `# Crie o gráfico de heatmap usando o seaborn`
#
# `sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')`
#
# `# Exiba o gráfico`
#
# `plt.show()`
#
# <br>
#
# 6. **Identificação de Outliers**
#
# Valores atípicos podem afetar a análise de dados, então é uma boa ideia identificar e entender quaisquer outliers potenciais em seu conjunto de dados. Você pode fazer isso graficamente usando boxplots, ou analiticamente usando métodos estatísticos.
#
# <br>
#
# 7. **Testes de Hipóteses**
#
# Dependendo do que você descobrir durante a análise exploratória, você pode querer realizar testes de hipóteses para determinar se os padrões que você observa são estatisticamente significativos.
#
# Lembre-se de que esses são apenas alguns passos básicos e a análise específica dependerá muito do conjunto de dados que você está usando e das questões que você está tentando responder.
#
# <br>
#
# 8. **Seleção de colunas**
#
# Você pode selecionar colunas em um DataFrame usando a sintaxe de colchetes ou usando o operador ponto.
#
# `df['nome_da_coluna']`
# `df.nome_da_coluna`
#
# <br>
#
# 9. **Seleção de linhas**
#
# Você pode selecionar linhas em um DataFrame usando a função loc para rótulos de linha ou iloc para posições de linha:
#
# `df.loc[rotulo_da_linha]`
# `df.iloc[posicao_da_linha]`
#
# <br>
#
# 10. **Filtragem**
#
# Você pode filtrar linhas em um DataFrame com base em uma condição:
#
# `df[df['nome_da_coluna'] > valor]`
#
# <br>
#
# 11. **Agrupamento**
#
# A função `groupby()` é usada para agrupar o `DataFrame` com base em uma ou mais colunas, e você pode aplicar funções agregadas como `mean()`, `
# min()`, `max()`, `sum()`, etc. ao grupo resultante:
#
# `df.groupby('nome_da_coluna').mean()`
#
# <br>
#
# 12. **Manipulação de valores ausentes**
#
# As funções `isnull()` e `notnull()` são usadas para detectar valores ausentes, e as funções `dropna()` e `fillna()` são usadas para tratar valores ausentes:
#
# `df.isnull()`
#
# `df.dropna()`
#
# `df.fillna(valor)`
#
# <br>
#
# 13. **Criação de novas colunas**
#
# Você pode criar novas colunas a partir de colunas existentes.
#
# `df['nova_coluna'] = df['coluna1'] + df['coluna2']`
#
# <br>
#
# 14. **Aplicando funções a colunas**
#
# Use o método `.apply()` para aplicar uma função a cada elemento de uma coluna.
#
# `# Aplica a função np.sqrt (raiz quadrada do NumPy) à coluna 'A'`
#
# `df['A'] = df['A'].apply(np.sqrt)`
#
# <br>
#
# 15. **Ordenando os dados**
#
# Use o método `.sort_values()` para ordenar o `DataFrame`.
#
# `# Ordena o DataFrame com base na coluna 'A'`
#
# `df = df.sort_values('A')`
#
# <br>
#
# 16. **Juntando DataFrames**
#
# Use os métodos `.merge()` e `.concat()` para juntar dois ou mais `DataFrames`.
#
# `# Junta dois DataFrames ao longo das colunas`
#
# `df = pd.concat([df1, df2], axis=1)`
#
# `# Merge de dois DataFrames com base em uma coluna chave`
#
# `df = pd.merge(df1, df2, on='key_column')`
#
# <br>
#
# Para saber mais:
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
#
# <br>
#
# 17. **Alterando o índice**
#
# Use o método `.set_index()` para alterar o índice do `DataFrame`.
#
# `# Define a coluna 'A' como índice`
#
# `df = df.set_index('A')`
#
# <br>
#
# 18. **Resetando o índice**
#
# Use o método `.reset_index()` para resetar o índice do `DataFrame`.
#
# `# Reset o índice`
# `df = df.reset_index()`
#
# <br>
#
# 19. **Renomeando colunas**
#
# Use o método `.rename()` para renomear colunas.
#
# `# Renomeia a coluna 'A' para 'new_A'`
#
# `df = df.rename(columns={'A': 'new_A'})`
#
# <br>
#
# 20. **Selecionando valores únicos**
#
# Use o método `.unique()` para obter valores únicos de uma coluna.
#
# `# Retorna valores únicos da coluna 'A'`
# `unique_values = df['A'].unique()``
#
# <br>
#
# 21. **Contando valores únicos**
#
# Use o método `.value_counts()` para contar a ocorrência de valores únicos em uma coluna.
#
# `# Conta ocorrências de valores únicos na coluna 'A'`
#
# `value_counts = df['A'].value_counts()`
#
# <br>
#
# 22. **Conversão de tipos de dados**
#
# Use o método `.astype()` para converter o tipo de dados de uma coluna.
#
# `# Converte a coluna 'A' para int`
#
# `df['A'] = df['A'].astype(int)`
#
# <br>
#
# As funções `pd.to_numeric()` e `pd.to_datetime()` são funções da biblioteca pandas em Python para converter os dados de uma coluna específica em tipos numéricos e de data/hora, respectivamente. Aqui está uma explicação de cada uma delas:
#
# 1. `pd.to_numeric(df[a]):`
#
# * `df[a]`: É a coluna do DataFrame df que você deseja converter para um tipo numérico.
# * `pd.to_numeric()`: É uma função que converte os valores da coluna em números. Se houver algum valor inválido ou não numérico na coluna, o pandas converterá esse valor para `NaN`.
#
# * Sintaxe correta: `df[a] = pd.to_numeric(df[a])`
#
# 2. `pd.to_datetime(df[a])`:
#
# * `df[a]`: É a coluna do DataFrame df que você deseja converter para o tipo de data/hora.
# * `pd.to_datetime()`: É uma função que converte os valores da coluna em objetos de data/hora do pandas.
# * Sintaxe correta: `df[a] = pd.to_datetime(df[a])`
